# %%
def get_hz_py_dic():
    py_hz_file = "pinyin2hanzi.txt"
    hz_py_dic = dict()
    py_dic = dict()
    hz_list = []
    py_list = []  
    py_hz_dic = dict()
    with open(py_hz_file, 'r', encoding='utf8') as fin:
        i = -1
        j = 0
        for line in fin.readlines():
            py, hz = line.split(' ')
            hzs = hz.strip('\n').split(' ')
            if(j == 0):
                py_list.append('a')
                py_dic['a'] = len(py_list) - 1
                py_hz_dic['a'] = hzs[0]
            else:
                py_list.append(py)
                py_dic[py] = len(py_list) - 1
                py_hz_dic[py] = hzs[0]
            j += 1

            hz = hz[:-1]
            for hanzi in hz:
                if(hz_py_dic.__contains__(hanzi) == False):
                    i += 1
                    hz_py_dic[hanzi] = []
                    hz_py_dic[hanzi].append(i)
                    hz_list.append(hanzi)
                hz_py_dic[hanzi].append(py)
    
    hz_py_dic['阿'][1] =hz_py_dic['啊'][1] = hz_py_dic['呵'][1] = hz_py_dic['锕'][1] =  hz_py_dic['吖'][1]=  hz_py_dic['腌'][1]=  hz_py_dic['嗄'][1]='a'
    return hz_py_dic, hz_list, py_list, py_dic, py_hz_dic

# %%
def train_params():
    '''
    hmm参数训练
    :return:
    '''
    dic, hzl, pyl, pyd, pyhzdic = get_hz_py_dic()
    hz_num = len(hzl)
    pi = [0 for i in range(8000)]
    pi = count_pi(dic, pi, hzl, hz_num)

    b = [[0 for aa in range(8000)] for bb in range(8000)]
    b = count_b(hzl, dic, b, pyd, pyl)

    a = [[0 for aaa in range(8000)] for bbb in range(8000)]
    a = count_a(dic, a)
    return a, b, pi, dic, hzl, pyl, pyd, pyhzdic

# %%
def count_pi(dic, pi, hz_list, i):
    file = "lexicon.txt"
    with open(file, 'r', encoding='utf8') as fin:
        for line in fin.readlines():
            lineset = line.strip('\n').split(' ')
            hanzi = lineset[0][0]
            py = lineset[1][:-1]
            if(dic.__contains__(hanzi) == False):
                i += 1
                dic[hanzi] = []
                dic[hanzi].append(i)
                dic[hanzi].append(py)
                hz_list.append(hanzi)
            pi[dic[hanzi][0]] = 1
    return pi

# %%
def count_a(hz_dic, a):
    file = "lexicon.txt"
    count_a = [0 for i in range(8000)]
    with open(file, 'r', encoding='utf8') as fin:
        for line in fin.readlines():
            lineset = line.strip('\n').split(' ')
            Q = lineset[0]
            for q in range(len(Q) - 1):
                qi = hz_dic[Q[q]][0]
                qj = hz_dic[Q[q + 1]][0]
                a[qi][qj] += 1
                count_a[qi] += 1

    for i in range(len(a)):
        for j in range(len(a[0])):
            if(count_a[i] == 0):
                count_a[i] += 1
            a[i][j] = a[i][j] / count_a[i]
    return a

# %%
def count_b(hzlist, dic, b, pydic, pylist):
    file = "lexicon.txt"
    tmplist = [0 for i in range(8000)]
    with open(file, 'r', encoding='utf8') as fin:
        for line in fin.readlines():
            lineset = line.strip('\n').split(' ')
            hanzi = lineset[0]
            for hz in range(len(hanzi)):
                py = lineset[hz + 1][:-1]
                if(dic.__contains__(hanzi[hz]) == False):
                    hzlist.append(hanzi[hz])
                    dic[hanzi[hz]] = []
                    dic[hanzi[hz]].append(len(hzlist) - 1)
                    dic[hanzi[hz]].append(py)

                j = dic[hanzi[hz]][0] #汉字序列
                if(pydic.__contains__(py) == False):
                    pylist.append(py)
                    pydic[py] = len(pylist) - 1
                k = pydic[py]
                b[j][k] += 1
                tmplist[j] += 1

    for i in range(len(b)):
        for j in range(len(b[0])):
            b[i][j] = b[i][j] / (tmplist[i] + 1) ##smooth
    return b

# %%
a, b, pi, dic, hzl, pyl, pyd, pyhzdic = train_params()

# %%
def print_AB(a, hzl):
    for i in range(len(a)):
        for j in range(len(a[0])):
            if a[i][j] > 0:
                print(str(hzl[i]) + " " + str(hzl[j]) + " :" + str(a[i][j]))

# %%
print_AB(b, hzl)
# Out:
# 阿 阿 :0.9636363636363636
# 阿 耙 :0.01818181818181818
# 啊 阿 :0.9090909090909091
# 呵 扳 :0.8888888888888888
# 爱 啊 :0.9857142857142858
# 暧 啊 :0.5
# 哀 啊 :0.9333333333333333
# 挨 啊 :0.9
# 埃 啊 :0.9411764705882353
# 诶 啊 :0.16666666666666666
# 诶 册 :0.6666666666666666
# 唉 啊 :0.75
# 隘 啊 :0.6666666666666666
# 艾 啊 :0.9
# 哎 啊 :0.8571428571428571
# 癌 啊 :0.9411764705882353
# 蔼 啊 :0.5
# 矮 啊 :0.8888888888888888
# 碍 啊 :0.875
# 皑 啊 :0.6666666666666666
# 安 呵 :0.9940476190476191
# 按 呵 :0.9565217391304348
# 桉 呵 :0.6666666666666666
# 氨 呵 :0.9166666666666666
# 铵 呵 :0.8333333333333334
# 庵 呵 :0.6666666666666666
# 俺 呵 :0.6666666666666666
# 鹌 呵 :0.5
# 胺 呵 :0.9
# 鞍 呵 :0.8571428571428571
# 案 呵 :0.9836065573770492
# 暗 呵 :0.96875
# 黯 呵 :0.6666666666666666
# 岸 呵 :0.9615384615384616
# 昂 锕 :0.9375
# 盎 锕 :0.75
# 肮 锕 :0.5
# 奥 吖 :0.9666666666666667
# 澳 吖 :0.8
# 懊 吖 :0.75
# 熬 吖 :0.8
# 傲 吖 :0.8571428571428571
# 嗷 吖 :0.75
# 敖 吖 :0.5
# 遨 吖 :0.5
# 鳌 吖 :0.5
# 袄 吖 :0.75
# 凹 吖 :0.8
# 坳 吖 :0.5
# 拗 吖 :0.25
# 拗 篦 :0.5
# 嚣 博 :0.8
# 巴 腌 :0.9873417721518988
# 爸 腌 :0.875
# 把 腌 :0.9655172413793104
# 吧 腌 :0.8888888888888888
# 靶 腌 :0.8
# 耙 腌 :0.3333333333333333
# 耙 弊 :0.3333333333333333
# 芭 腌 :0.75
# 笆 腌 :0.6666666666666666
# 疤 腌 :0.75
# 粑 腌 :0.6666666666666666
# 八 腌 :0.9902912621359223
# 扒 腌 :0.5
# 扒 弊 :0.25
# 叭 腌 :0.8333333333333334
# 拔 腌 :0.9411764705882353
# 跋 腌 :0.9
# 霸 腌 :0.9444444444444444
# 罢 腌 :0.9375
# 捌 腌 :0.5
# 坝 腌 :0.875
# 白 嗄 :0.9948453608247423
# 伯 嗄 :0.023809523809523808
# 伯 艾 :0.9523809523809523
# 柏 嗄 :0.6428571428571429
# 柏 艾 :0.2857142857142857
# 百 嗄 :0.9891304347826086
# 佰 嗄 :0.6666666666666666
# 稗 嗄 :0.5
# 败 嗄 :0.967741935483871
# 呗 瑷 :0.5
# 拜 嗄 :0.975
# 摆 嗄 :0.9285714285714286
# 掰 嗄 :0.5
# 半 爱 :0.9903846153846154
# 伴 爱 :0.9333333333333333
# 绊 爱 :0.8
# 拌 爱 :0.8333333333333334
# 版 爱 :0.9714285714285714
# 板 爱 :0.9873417721518988
# 扳 爱 :0.875
# 坂 爱 :0.5
# 阪 爱 :0.5
# 般 爱 :0.9090909090909091
# 搬 爱 :0.9090909090909091
# 瘢 爱 :0.5
# 班 爱 :0.9848484848484849
# 斑 爱 :0.9545454545454546
# 办 爱 :0.9861111111111112
# 瓣 爱 :0.875
# 颁 爱 :0.875
# 扮 爱 :0.8
# 邦 嫒 :0.9411764705882353
# 绑 嫒 :0.8
# 梆 嫒 :0.8
# 帮 嫒 :0.9545454545454546
# 榜 嫒 :0.9166666666666666
# 傍 嫒 :0.6666666666666666
# 磅 嫒 :0.3333333333333333
# 磅 壁 :0.3333333333333333
# 膀 嫒 :0.6666666666666666
# 膀 壁 :0.2222222222222222
# 镑 嫒 :0.6666666666666666
# 谤 嫒 :0.5
# 棒 嫒 :0.9285714285714286
# 蚌 嫒 :0.6
# 蚌 锿 :0.2
# 包 暧 :0.9857142857142858
# 饱 暧 :0.9375
# 刨 暧 :0.7142857142857143
# 刨 碧 :0.14285714285714285
# 胞 暧 :0.96875
# 炮 暧 :0.043478260869565216
# 炮 碧 :0.9347826086956522
# 苞 暧 :0.8
# 鲍 暧 :0.8
# 雹 暧 :0.75
# 报 暧 :0.993103448275862
# 保 暧 :0.9911504424778761
# 褓 暧 :0.5
# 葆 暧 :0.5
# 堡 暧 :0.8947368421052632
# 堡 哎 :0.05263157894736842
# 煲 暧 :0.5
# 褒 暧 :0.8
# 宝 暧 :0.9818181818181818
# 薄 暧 :0.3333333333333333
# 薄 艾 :0.6296296296296297
# 豹 暧 :0.75
# 暴 暧 :0.9555555555555556
# 暴 币 :0.022222222222222223
# 爆 暧 :0.9411764705882353
# 剥 暧 :0.2857142857142857
# 剥 艾 :0.6428571428571429
# 趵 暧 :0.6666666666666666
# 鸨 暧 :0.5
# 被 瑷 :0.975
# 倍 瑷 :0.9411764705882353
# 焙 瑷 :0.8
# 蓓 瑷 :0.5
# 北 瑷 :0.9906542056074766
# 背 瑷 :0.9743589743589743
# 臂 瑷 :0.07142857142857142
# 臂 挨 :0.8571428571428571
# 杯 瑷 :0.9285714285714286
# 贝 瑷 :0.9705882352941176
# 狈 瑷 :0.75
# 钡 瑷 :0.75
# 辈 瑷 :0.9565217391304348
# 悲 瑷 :0.9411764705882353
# 卑 瑷 :0.9230769230769231
# 碑 瑷 :0.9230769230769231
# 悖 瑷 :0.5
# 备 瑷 :0.9859154929577465
# 惫 瑷 :0.75
# 鞴 瑷 :0.6666666666666666
# 本 哀 :0.9953488372093023
# 苯 哀 :0.9411764705882353
# 笨 哀 :0.8
# 奔 哀 :0.95
# 贲 哀 :0.5
# 夯 版 :0.5
# 崩 锿 :0.8888888888888888
# 绷 锿 :0.8
# 蹦 锿 :0.75
# 嘣 锿 :0.5
# 泵 锿 :0.9411764705882353
# 甭 锿 :0.75
# 迸 锿 :0.6666666666666666
# 匕 挨 :0.5
# 比 挨 :0.9903846153846154
# 毙 挨 :0.8
# 庇 挨 :0.6666666666666666
# 毖 挨 :0.5
# 毕 挨 :0.9444444444444444
# 陛 挨 :0.5
# 必 挨 :0.9696969696969697
# 秘 挨 :0.21052631578947367
# 秘 苯 :0.7368421052631579
# 笔 挨 :0.9830508474576272
# 鼻 挨 :0.9285714285714286
# 敝 挨 :0.6666666666666666
# 弊 挨 :0.9
# 辟 挨 :0.42857142857142855
# 辟 裨 :0.42857142857142855
# 碧 挨 :0.9166666666666666
# 璧 挨 :0.75
# 壁 挨 :0.9642857142857143
# 避 挨 :0.9565217391304348
# 裨 挨 :0.5
# 婢 挨 :0.5
# 俾 瑷 :0.5
# 痹 挨 :0.8
# 蔽 挨 :0.875
# 币 挨 :0.96875
# 逼 挨 :0.9166666666666666
# 彼 挨 :0.9166666666666666
# 闭 挨 :0.9545454545454546
# 拂 魃 :0.8
# 鄙 挨 :0.8571428571428571
# 边 埃 :0.9903846153846154
# 扁 埃 :0.875
# 编 埃 :0.9777777777777777
# 遍 埃 :0.9333333333333333
# 鳊 埃 :0.5
# 煸 埃 :0.5
# 蝙 埃 :0.5
# 匾 埃 :0.75
# 辩 埃 :0.9583333333333334
# 辨 埃 :0.8571428571428571
# 辫 埃 :0.8
# 卞 埃 :0.5
# 汴 埃 :0.5
# 便 埃 :0.8837209302325582
# 便 俾 :0.09302325581395349
# 鞭 埃 :0.9230769230769231
# 变 埃 :0.9908256880733946
# 贬 埃 :0.8333333333333334
# 表 诶 :0.990990990990991
# 裱 诶 :0.6666666666666666
# 标 诶 :0.9875
# 膘 诶 :0.6666666666666666
# 镖 诶 :0.6666666666666666
# 骠 诶 :0.5
# 勺 鳖 :0.6666666666666666
# 别 唉 :0.984375
# 鳖 唉 :0.5
# 憋 唉 :0.6666666666666666
# 瘪 唉 :0.6666666666666666
# 宾 隘 :0.96
# 滨 隘 :0.9166666666666666
# 膑 隘 :0.6666666666666666
# 殡 隘 :0.75
# 槟 隘 :0.5
# 槟 嗌 :0.25
# 摈 隘 :0.75
# 缤 隘 :0.6666666666666666
# 鬓 隘 :0.8
# 斌 隘 :0.8
# 彬 隘 :0.875
# 濒 隘 :0.8
# 并 嗌 :0.96875
# 饼 嗌 :0.9285714285714286
# 屏 痹 :0.8888888888888888
# 摒 嗌 :0.5
# 丙 嗌 :0.9
# 炳 嗌 :0.6666666666666666
# 柄 嗌 :0.8888888888888888
# 病 嗌 :0.9925373134328358
# 兵 嗌 :0.9897959183673469
# 冰 嗌 :0.9811320754716981
# 秉 嗌 :0.75
# 禀 嗌 :0.5
# 脖 艾 :0.6666666666666666
# 勃 艾 :0.9523809523809523
# 渤 艾 :0.6666666666666666
# 鹁 艾 :0.5
# 波 艾 :0.989010989010989
# 玻 艾 :0.9411764705882353
# 跛 艾 :0.5
# 拨 艾 :0.9230769230769231
# 菠 艾 :0.6666666666666666
# 簸 艾 :0.6666666666666666
# 泊 艾 :0.6923076923076923
# 泊 弼 :0.23076923076923078
# 舶 艾 :0.5
# 箔 艾 :0.6666666666666666
# 博 艾 :0.9629629629629629
# 膊 艾 :0.8
# 搏 艾 :0.8333333333333334
# 播 艾 :0.9722222222222222
# 驳 艾 :0.9
# 帛 艾 :0.5
# 钹 艾 :0.5
# 钵 艾 :0.5
# 卜 艾 :0.5
# 卜 哎 :0.3333333333333333
# 不 哎 :0.9981851179673321
# 钚 哎 :0.5
# 布 哎 :0.9917355371900827
# 怖 哎 :0.8333333333333334
# 补 哎 :0.975609756097561
# 捕 哎 :0.9473684210526315
# 哺 哎 :0.75
# 埔 币 :0.6666666666666666
# 簿 哎 :0.8571428571428571
# 埠 哎 :0.8333333333333334
# 部 哎 :0.9935483870967742
# 步 哎 :0.9857142857142858
# 擦 砹 :0.9375
# 嚓 砹 :0.3333333333333333
# 嚓 埯 :0.3333333333333333
# 拆 砹 :0.2222222222222222
# 拆 胺 :0.6666666666666666
# 才 癌 :0.967741935483871
# 材 癌 :0.9787234042553191
# 财 癌 :0.9795918367346939
# 采 癌 :0.9807692307692307
# 菜 癌 :0.9850746268656716
# 彩 癌 :0.9791666666666666
# 踩 癌 :0.5
# 睬 癌 :0.75
# 蔡 癌 :0.75
# 裁 癌 :0.96875
# 猜 癌 :0.875
# 参 蔼 :0.8636363636363636
# 参 蹩 :0.06818181818181818
# 参 嘈 :0.045454545454545456
# 掺 鞍 :0.6666666666666666
# 惨 蔼 :0.9444444444444444
# 残 蔼 :0.9642857142857143
# 餐 蔼 :0.9615384615384616
# 蚕 蔼 :0.9444444444444444
# 灿 蔼 :0.75
# 惭 蔼 :0.75
# 璨 蔼 :0.5
# 藏 霭 :0.46808510638297873
# 藏 步 :0.5106382978723404
# 仓 霭 :0.9285714285714286
# 舱 霭 :0.9
# 苍 霭 :0.9411764705882353
# 沧 霭 :0.8
# 曹 矮 :0.8888888888888888
# 草 矮 :0.9873417721518988
# 槽 矮 :0.8888888888888888
# 漕 矮 :0.5
# 嘈 矮 :0.6666666666666666
# 操 矮 :0.967741935483871
# 糙 矮 :0.75
# 册 碍 :0.9285714285714286
# 策 碍 :0.9642857142857143
# 侧 碍 :0.8888888888888888
# 侧 瓿 :0.05555555555555555
# 测 碍 :0.972972972972973
# 厕 碍 :0.75
# 层 皑 :0.9818181818181818
# 曾 皑 :0.5833333333333334
# 曾 礤 :0.3333333333333333
# 蹭 皑 :0.6666666666666666
# 次 安 :0.9857142857142858
# 茨 安 :0.9333333333333333
# 此 安 :0.9787234042553191
# 疵 安 :0.75
# 雌 安 :0.875
# 词 安 :0.9772727272727273
# 伺 安 :0.3333333333333333
# 伺 镖 :0.3333333333333333
# 祠 安 :0.75
# 辞 安 :0.9642857142857143
# 兹 拆 :0.8888888888888888
# 慈 安 :0.9230769230769231
# 磁 安 :0.9767441860465116
# 刺 安 :0.9642857142857143
# 瓷 安 :0.9230769230769231
# 赐 安 :0.8571428571428571
# 差 安 :0.02857142857142857
# 差 埯 :0.7428571428571429
# 差 胺 :0.21428571428571427
# 从 按 :0.9863013698630136
# 丛 按 :0.9166666666666666
# 匆 按 :0.8571428571428571
# 葱 按 :0.9166666666666666
# 囱 按 :0.5
# 聪 按 :0.8333333333333334
# 凑 桉 :0.8888888888888888
# 粗 氨 :0.975609756097561
# 促 氨 :0.95
# 簇 氨 :0.8
# 醋 氨 :0.8571428571428571
# 猝 氨 :0.5
# 蹙 氨 :0.5
# 窜 铵 :0.8
# 蹿 铵 :0.5
# 撺 铵 :0.5
# 攒 部 :0.6666666666666666
# 汆 铵 :0.5
# 篡 铵 :0.8333333333333334
# 崔 庵 :0.5
# 催 庵 :0.9333333333333333
# 摧 庵 :0.8333333333333334
# 璀 庵 :0.5
# 萃 庵 :0.8
# 翠 庵 :0.875
# 粹 庵 :0.8571428571428571
# 悴 庵 :0.5
# 瘁 庵 :0.5
# 啐 庵 :0.5
# 淬 庵 :0.75
# 衰 庵 :0.15789473684210525
# 衰 槟 :0.7368421052631579
# 衰 缤 :0.05263157894736842
# 脆 庵 :0.875
# 村 俺 :0.9583333333333334
# 寸 俺 :0.9166666666666666
# 忖 俺 :0.5
# 存 俺 :0.9838709677419355
# 蹲 吧 :0.75
# 皴 俺 :0.5
# 错 鹌 :0.9655172413793104
# 措 鹌 :0.9333333333333333
# 挫 鹌 :0.8571428571428571
# 锉 鹌 :0.6666666666666666
# 搓 鹌 :0.6666666666666666
# 磋 鹌 :0.75
# 撮 鹌 :0.5
# 撮 踩 :0.25
# 查 埯 :0.9726027397260274
# 查 睬 :0.0136986301369863
# 楂 埯 :0.3333333333333333
# 楂 睬 :0.3333333333333333
# 茶 埯 :0.9791666666666666
# 搽 埯 :0.5
# 插 埯 :0.9615384615384616
# 锸 埯 :0.5
# 察 埯 :0.9722222222222222
# 叉 埯 :0.9166666666666666
# 杈 埯 :0.75
# 诧 埯 :0.6666666666666666
# 姹 埯 :0.5
# 茬 埯 :0.8333333333333334
# 岔 埯 :0.875
# 刹 埯 :0.4
# 刹 飙 :0.4
# 柴 胺 :0.9166666666666666
# 豺 胺 :0.6666666666666666
# 产 鞍 :0.9954128440366973
# 铲 鞍 :0.8571428571428571
# 单 鞍 :0.0234375
# 单 遨 :0.9609375
# 单 飑 :0.0078125
# 禅 鞍 :0.8571428571428571
# 蝉 鞍 :0.6666666666666666
# 阐 鞍 :0.75
# 馋 鞍 :0.5
# 搀 鞍 :0.6666666666666666
# 孱 鞍 :0.5
# 潺 鞍 :0.6666666666666666
# 镡 搏 :0.5
# 缠 鞍 :0.8333333333333334
# 颤 鞍 :0.75
# 颤 裁 :0.125
# 谄 鞍 :0.5
# 忏 鞍 :0.5
# 厂 案 :0.9846153846153847
# 长 案 :0.49624060150375937
# 长 猜 :0.5
# 怅 案 :0.5
# 场 案 :0.9939024390243902
# 肠 案 :0.9545454545454546
# 畅 案 :0.9473684210526315
# 昌 案 :0.9583333333333334
# 唱 案 :0.9714285714285714
# 倡 案 :0.8571428571428571
# 娼 案 :0.6666666666666666
# 猖 案 :0.75
# 鲳 案 :0.5
# 菖 案 :0.5
# 尝 案 :0.875
# 偿 案 :0.9333333333333333
# 倘 豳 :0.8
# 徜 案 :0.5
# 敞 案 :0.8333333333333334
# 常 案 :0.9873417721518988
# 嫦 案 :0.5
# 裳 别 :0.5
# 超 暗 :0.9787234042553191
# 吵 暗 :0.9090909090909091
# 炒 暗 :0.8333333333333334
# 钞 暗 :0.75
# 抄 暗 :0.9
# 朝 暗 :0.7192982456140351
# 朝 参 :0.2631578947368421
# 潮 暗 :0.9696969696969697
# 嘲 暗 :0.8
# 巢 暗 :0.9
# 剿 邦 :0.25
# 剿 帮 :0.5
# 绰 暗 :0.2
# 绰 嗷 :0.6
# 车 揞 :0.9846153846153847
# 车 谤 :0.010256410256410256
# 撤 揞 :0.9333333333333333
# 澈 揞 :0.5
# 扯 揞 :0.875
# 彻 揞 :0.9090909090909091
# 尺 揞 :0.21739130434782608
# 尺 岸 :0.7391304347826086
# 掣 揞 :0.6666666666666666
# 陈 黯 :0.96
# 沉 黯 :0.9767441860465116
# 尘 黯 :0.9473684210526315
# 称 黯 :0.1320754716981132
# 称 谙 :0.8490566037735849
# 臣 黯 :0.9333333333333333
# 秤 谙 :0.8888888888888888
# 晨 黯 :0.9
# 辰 黯 :0.8888888888888888
# 趁 黯 :0.8
# 衬 黯 :0.9166666666666666
# 忱 黯 :0.5
# 琛 黯 :0.5
# 橙 黯 :0.42857142857142855
# 橙 谙 :0.42857142857142855
# 郴 黯 :0.5
# 宸 黯 :0.5
# 碜 黯 :0.5
# 嗔 黯 :0.5
# 抻 黯 :0.5
# 成 谙 :0.9955156950672646
# 城 谙 :0.9896907216494846
# 诚 谙 :0.9523809523809523
# 柽 谙 :0.5
# 呈 谙 :0.8571428571428571
# 程 谙 :0.9906542056074766
# 逞 谙 :0.75
# 承 谙 :0.9772727272727273
# 盛 谙 :0.05405405405405406
# 盛 宾 :0.918918918918919
# 乘 谙 :0.92
# 乘 宾 :0.04
# 撑 谙 :0.9
# 澄 谙 :0.75
# 惩 谙 :0.8888888888888888
# 铛 鳌 :0.75
# 丞 谙 :0.6666666666666666
# 骋 谙 :0.5
# 吃 岸 :0.9722222222222222
# 齿 岸 :0.9411764705882353
# 持 岸 :0.975
# 池 岸 :0.9666666666666667
# 弛 岸 :0.5
# 驰 岸 :0.9
# 迟 岸 :0.9285714285714286
# 赤 岸 :0.9655172413793104
# 哧 岸 :0.5
# 痴 岸 :0.8333333333333334
# 耻 岸 :0.875
# 翅 岸 :0.8333333333333334
# 斥 岸 :0.9375
# 叱 岸 :0.5
# 匙 岸 :0.3333333333333333
# 匙 滨 :0.3333333333333333
# 炽 岸 :0.8333333333333334
# 茌 岸 :0.5
# 侈 岸 :0.75
# 冲 昂 :0.9807692307692307
# 种 昂 :0.009345794392523364
# 种 蚕 :0.9813084112149533
# 忡 昂 :0.6666666666666666
# 崇 昂 :0.9166666666666666
# 虫 昂 :0.9807692307692307
# 充 昂 :0.96875
# 宠 昂 :0.8333333333333334
# 重 昂 :0.22297297297297297
# 重 蚕 :0.7702702702702703
# 憧 昂 :0.5
# 涌 补 :0.875
# 舂 昂 :0.5
# 抽 盎 :0.967741935483871
# 愁 盎 :0.9166666666666666
# 瞅 盎 :0.6666666666666666
# 丑 盎 :0.9090909090909091
# 筹 盎 :0.9523809523809523
# 畴 盎 :0.75
# 踌 盎 :0.6666666666666666
# 绸 盎 :0.9
# 稠 盎 :0.75
# 仇 盎 :0.8461538461538461
# 仇 遍 :0.07692307692307693
# 臭 盎 :0.8571428571428571
# 臭 帛 :0.07142857142857142
# 酬 盎 :0.8888888888888888
# 出 肮 :0.9961538461538462
# 础 肮 :0.9166666666666666
# 黜 肮 :0.5
# 刍 肮 :0.5
# 雏 肮 :0.8
# 处 肮 :0.9882352941176471
# 初 肮 :0.9761904761904762
# 除 肮 :0.9782608695652174
# 滁 肮 :0.5
# 楚 肮 :0.9285714285714286
# 储 肮 :0.9583333333333334
# 躇 肮 :0.6666666666666666
# 触 肮 :0.9583333333333334
# 锄 肮 :0.6666666666666666
# 厨 肮 :0.8571428571428571
# 橱 肮 :0.8333333333333334
# 矗 肮 :0.75
# 畜 肮 :0.6190476190476191
# 畜 擘 :0.3333333333333333
# 搐 肮 :0.5
# 杵 肮 :0.5
# 揣 奥 :0.6666666666666666
# 嘬 踩 :0.5
# 船 澳 :0.9848484848484849
# 传 澳 :0.926605504587156
# 传 藏 :0.06422018348623854
# 川 澳 :0.9615384615384616
# 穿 澳 :0.9615384615384616
# 串 澳 :0.8571428571428571
# 喘 澳 :0.8888888888888888
# 椽 澳 :0.5
# 创 懊 :0.9743589743589743
# 疮 懊 :0.8333333333333334
# 闯 懊 :0.9
# 床 懊 :0.9722222222222222
# 窗 懊 :0.9473684210526315
# 吹 熬 :0.95
# 炊 熬 :0.8333333333333334
# 锤 熬 :0.9
# 槌 熬 :0.5
# 垂 熬 :0.96
# 捶 熬 :0.5
# 陲 熬 :0.5
# 椎 舱 :0.8888888888888888
# 春 傲 :0.9838709677419355
# 蠢 傲 :0.8
# 醇 傲 :0.9090909090909091
# 淳 傲 :0.75
# 纯 傲 :0.96
# 唇 傲 :0.75
# 鹑 傲 :0.5
# 辍 嗷 :0.6666666666666666
# 戳 嗷 :0.75
# 龊 嗷 :0.5
# 大 敖 :0.989100817438692
# 大 廒 :0.009536784741144414
# 达 敖 :0.9868421052631579
# 打 敖 :0.9933333333333333
# 答 敖 :0.9473684210526315
# 搭 敖 :0.9230769230769231
# 嗒 敖 :0.5
# 沓 敖 :0.3333333333333333
# 沓 斌 :0.3333333333333333
# 瘩 敖 :0.5
# 耷 敖 :0.5
# 带 廒 :0.9902912621359223
# 代 廒 :0.9911504424778761
# 玳 廒 :0.5
# 戴 廒 :0.9375
# 待 廒 :0.972972972972973
# 贷 廒 :0.9444444444444444
# 袋 廒 :0.9333333333333333
# 呆 啊 :0.125
# 呆 廒 :0.75
# 岱 廒 :0.6666666666666666
# 傣 廒 :0.6666666666666666
# 黛 廒 :0.5
# 逮 廒 :0.8
# 殆 廒 :0.5
# 歹 廒 :0.8
# 怠 廒 :0.6666666666666666
# 弹 遨 :0.6037735849056604
# 弹 濒 :0.37735849056603776
# 掸 遨 :0.5
# 惮 遨 :0.5
# 郸 遨 :0.5
# 旦 遨 :0.9230769230769231
# 但 遨 :0.8888888888888888
# 担 遨 :0.9411764705882353
# 胆 遨 :0.9583333333333334
# 丹 遨 :0.9642857142857143
# 蛋 遨 :0.9714285714285714
# 淡 遨 :0.96875
# 氮 遨 :0.9230769230769231
# 诞 遨 :0.875
# 耽 遨 :0.75
# 石 遨 :0.006578947368421052
# 石 滨 :0.9868421052631579
# 眈 遨 :0.6666666666666666
# 当 鳌 :0.9910714285714286
# 挡 鳌 :0.9230769230769231
# 档 鳌 :0.9230769230769231
# 裆 鳌 :0.5
# 党 鳌 :0.9900990099009901
# 荡 鳌 :0.9722222222222222
# 岛 骜 :0.9818181818181818
# 捣 骜 :0.875
# 到 骜 :0.9893617021276596
# 道 骜 :0.9946524064171123
# 倒 骜 :0.9841269841269841
# 刀 骜 :0.9767441860465116
# 叨 骜 :0.6666666666666666
# 叨 玢 :0.16666666666666666
# 导 骜 :0.9866666666666667
# 盗 骜 :0.9333333333333333
# 稻 骜 :0.9444444444444444
# 蹈 骜 :0.8
# 悼 骜 :0.8571428571428571
# 焘 玢 :0.5
# 祷 骜 :0.75
# 氘 骜 :0.5
# 的 螯 :0.8103448275862069
# 的 岙 :0.1724137931034483
# 得 螯 :0.9659863945578231
# 得 螬 :0.027210884353741496
# 德 螯 :0.9901960784313726
# 地 螯 :0.015915119363395226
# 地 岙 :0.9814323607427056
# 邓 獒 :0.8333333333333334
# 灯 獒 :0.9830508474576272
# 登 獒 :0.9666666666666667
# 蹬 獒 :0.5
# 瞪 獒 :0.75
# 凳 獒 :0.75
# 噔 獒 :0.5
# 等 獒 :0.989010989010989
# 帝 岙 :0.9696969696969697
# 蒂 岙 :0.9333333333333333
# 谛 岙 :0.75
# 缔 岙 :0.8571428571428571
# 弟 岙 :0.9736842105263158
# 娣 岙 :0.5
# 递 岙 :0.9230769230769231
# 第 岙 :0.9761904761904762
# 低 岙 :0.98
# 底 螯 :0.01694915254237288
# 底 岙 :0.9661016949152542
# 抵 岙 :0.9565217391304348
# 诋 岙 :0.5
# 堤 岙 :0.8571428571428571
# 提 岙 :0.015384615384615385
# 提 屏 :0.9692307692307692
# 迪 岙 :0.9230769230769231
# 滴 岙 :0.9166666666666666
# 嘀 岙 :0.6666666666666666
# 嫡 岙 :0.6666666666666666
# 敌 岙 :0.9705882352941176
# 邸 岙 :0.75
# 狄 岙 :0.75
# 笛 岙 :0.9
# 涤 岙 :0.8
# 店 袄 :0.9814814814814815
# 掂 袄 :0.6666666666666666
# 惦 袄 :0.75
# 踮 袄 :0.5
# 点 袄 :0.9933333333333333
# 玷 袄 :0.5
# 电 袄 :0.9974293059125964
# 垫 袄 :0.9090909090909091
# 碘 袄 :0.8333333333333334
# 典 袄 :0.9761904761904762
# 淀 袄 :0.875
# 靛 袄 :0.6666666666666666
# 殿 袄 :0.8888888888888888
# 癜 袄 :0.5
# 甸 袄 :0.8
# 滇 袄 :0.6666666666666666
# 巅 袄 :0.5
# 颠 袄 :0.9090909090909091
# 癫 袄 :0.6666666666666666
# 奠 袄 :0.8
# 佃 袄 :0.8333333333333334
# 调 凹 :0.6055045871559633
# 调 丙 :0.3853211009174312
# 雕 凹 :0.9230769230769231
# 凋 凹 :0.8
# 碉 凹 :0.5
# 掉 凹 :0.9583333333333334
# 刁 凹 :0.6666666666666666
# 叼 凹 :0.5
# 吊 凹 :0.9565217391304348
# 钓 凹 :0.8
# 貂 凹 :0.6666666666666666
# 鸟 凹 :0.058823529411764705
# 鸟 庇 :0.8823529411764706
# 谍 坳 :0.8333333333333334
# 碟 坳 :0.8333333333333334
# 蝶 坳 :0.75
# 牒 坳 :0.5
# 喋 坳 :0.6666666666666666
# 跌 坳 :0.8571428571428571
# 叠 坳 :0.8
# 迭 坳 :0.8
# 定 拗 :0.994475138121547
# 锭 拗 :0.8
# 腚 拗 :0.5
# 丁 拗 :0.9705882352941176
# 订 拗 :0.9565217391304348
# 盯 拗 :0.6666666666666666
# 钉 拗 :0.9
# 叮 拗 :0.8
# 顶 拗 :0.9777777777777777
# 鼎 拗 :0.9090909090909091
# 铤 柄 :0.5
# 丢 嚣 :0.8888888888888888
# 动 媪 :0.9974619289340102
# 东 媪 :0.9924242424242424
# 栋 媪 :0.6666666666666666
# 冻 媪 :0.9375
# 胨 媪 :0.5
# 洞 媪 :0.9642857142857143
# 侗 病 :0.5
# 恫 媪 :0.5
# 冬 媪 :0.9655172413793104
# 咚 媪 :0.5
# 董 媪 :0.9166666666666666
# 懂 媪 :0.875
# 都 巴 :0.1388888888888889
# 都 岜 :0.8333333333333334
# 斗 巴 :0.9827586206896551
# 抖 巴 :0.8571428571428571
# 豆 巴 :0.9714285714285714
# 逗 巴 :0.8
# 痘 巴 :0.5
# 兜 巴 :0.8333333333333334
# 篼 巴 :0.5
# 陡 巴 :0.8
# 窦 巴 :0.6666666666666666
# 读 岜 :0.9696969696969697
# 渎 岜 :0.6666666666666666
# 牍 岜 :0.5
# 犊 岜 :0.75
# 度 岜 :0.9845360824742269
# 度 靶 :0.010309278350515464
# 渡 岜 :0.9565217391304348
# 镀 岜 :0.875
# 杜 岜 :0.9411764705882353
# 肚 岜 :0.9090909090909091
# 毒 岜 :0.9791666666666666
# 独 岜 :0.9811320754716981
# 睹 岜 :0.8
# 赌 岜 :0.8333333333333334
# 堵 岜 :0.875
# 嘟 岜 :0.8333333333333334
# 督 岜 :0.95
# 笃 岜 :0.5
# 妒 岜 :0.5
# 顿 岜 :0.03571428571428571
# 顿 吧 :0.9285714285714286
# 段 爸 :0.9714285714285714
# 锻 爸 :0.9090909090909091
# 缎 爸 :0.8571428571428571
# 煅 爸 :0.5
# 断 爸 :0.9859154929577465
# 短 爸 :0.9782608695652174
# 端 爸 :0.9772727272727273
# 对 把 :0.9930555555555556
# 队 把 :0.9903846153846154
# 堆 把 :0.9285714285714286
# 兑 把 :0.8888888888888888
# 敦 獒 :0.06666666666666667
# 敦 把 :0.06666666666666667
# 敦 吧 :0.8
# 吨 吧 :0.8571428571428571
# 钝 吧 :0.75
# 盹 吧 :0.5
# 炖 吧 :0.5
# 砘 吧 :0.5
# 沌 吧 :0.5
# 囤 吧 :0.3333333333333333
# 囤 邴 :0.3333333333333333
# 墩 吧 :0.6666666666666666
# 盾 吧 :0.9444444444444444
# 多 靶 :0.9929078014184397
# 哆 靶 :0.5
# 夺 靶 :0.9583333333333334
# 朵 靶 :0.75
# 垛 靶 :0.6666666666666666
# 躲 靶 :0.9
# 跺 靶 :0.6666666666666666
# 剁 靶 :0.5
# 舵 靶 :0.6
# 舵 脖 :0.2
# 踱 靶 :0.6666666666666666
# 咄 靶 :0.6666666666666666
# 堕 靶 :0.8
# 惰 靶 :0.75
# 掇 靶 :0.6666666666666666
# 鄂 耙 :0.6666666666666666
# 萼 耙 :0.5
# 腭 耙 :0.5
# 愕 耙 :0.6666666666666666
# 颚 耙 :0.6666666666666666
# 额 耙 :0.9787234042553191
# 俄 耙 :0.9444444444444444
# 饿 耙 :0.8
# 娥 耙 :0.75
# 峨 耙 :0.8
# 鹅 耙 :0.8888888888888888
# 蛾 耙 :0.6666666666666666
# 哦 耙 :0.16666666666666666
# 哦 濞 :0.5
# 哦 菠 :0.16666666666666666
# 锇 耙 :0.5
# 婀 耙 :0.5
# 屙 耙 :0.5
# 恶 耙 :0.85
# 恶 簸 :0.125
# 噩 耙 :0.5
# 垩 耙 :0.5
# 厄 耙 :0.75
# 扼 耙 :0.8571428571428571
# 轭 耙 :0.75
# 呃 耙 :0.5
# 遏 耙 :0.75
# 讹 耙 :0.75
# 恩 芭 :0.9583333333333334
# 摁 芭 :0.5
# 二 笆 :0.994475138121547
# 而 笆 :0.9879518072289156
# 尔 笆 :0.9938650306748467
# 迩 笆 :0.5
# 儿 笆 :0.9962264150943396
# 耳 笆 :0.9714285714285714
# 洱 笆 :0.5
# 饵 笆 :0.75
# 贰 笆 :0.5
# 发 疤 :0.9963768115942029
# 法 疤 :0.9964788732394366
# 砝 疤 :0.5
# 伐 疤 :0.9545454545454546
# 阀 疤 :0.9375
# 筏 疤 :0.75
# 垡 疤 :0.6666666666666666
# 乏 疤 :0.9090909090909091
# 罚 疤 :0.9285714285714286
# 反 粑 :0.991869918699187
# 贩 粑 :0.9
# 饭 粑 :0.9714285714285714
# 返 粑 :0.9285714285714286
# 凡 粑 :0.9473684210526315
# 帆 粑 :0.8333333333333334
# 矾 粑 :0.6666666666666666
# 梵 粑 :0.6666666666666666
# 番 粑 :0.9166666666666666
# 翻 粑 :0.975
# 藩 粑 :0.8
# 蕃 粑 :0.5
# 范 粑 :0.9523809523809523
# 犯 粑 :0.975609756097561
# 樊 粑 :0.6666666666666666
# 繁 粑 :0.9642857142857143
# 泛 粑 :0.9285714285714286
# 烦 粑 :0.9333333333333333
# 方 钯 :0.9948453608247423
# 放 钯 :0.9907407407407407
# 房 钯 :0.9871794871794872
# 防 钯 :0.9891304347826086
# 芳 钯 :0.95
# 访 钯 :0.9473684210526315
# 纺 钯 :0.9583333333333334
# 仿 钯 :0.9333333333333333
# 坊 钯 :0.9090909090909091
# 妨 钯 :0.875
# 肪 钯 :0.75
# 彷 壁 :0.5
# 费 八 :0.987012987012987
# 沸 八 :0.9
# 飞 八 :0.984375
# 废 八 :0.9722222222222222
# 肥 八 :0.98
# 非 八 :0.9846153846153847
# 菲 八 :0.9230769230769231
# 啡 八 :0.875
# 扉 八 :0.75
# 诽 八 :0.5
# 痱 八 :0.5
# 绯 八 :0.5
# 匪 八 :0.9090909090909091
# 斐 八 :0.75
# 翡 八 :0.5
# 蜚 八 :0.6666666666666666
# 霏 八 :0.6666666666666666
# 吠 八 :0.5
# 妃 八 :0.8
# 肺 八 :0.9375
# 分 扒 :0.9966887417218543
# 份 扒 :0.9696969696969697
# 粉 扒 :0.98
# 汾 扒 :0.8
# 纷 扒 :0.9230769230769231
# 酚 扒 :0.9
# 吩 扒 :0.5
# 芬 扒 :0.9090909090909091
# 忿 扒 :0.6666666666666666
# 氛 扒 :0.5
# 坟 扒 :0.75
# 奋 扒 :0.9523809523809523
# 态 彬 :0.9772727272727273
# 粪 扒 :0.9
# 愤 扒 :0.9545454545454546
# 焚 扒 :0.8571428571428571
# 风 叭 :0.9950248756218906
# 疯 叭 :0.8
# 讽 叭 :0.8
# 砜 叭 :0.5
# 枫 叭 :0.75
# 封 叭 :0.975609756097561
# 丰 叭 :0.9714285714285714
# 冯 叭 :0.75
# 峰 叭 :0.96
# 锋 叭 :0.9545454545454546
# 蜂 叭 :0.95
# 烽 叭 :0.6666666666666666
# 逢 叭 :0.9090909090909091
# 缝 叭 :0.95
# 奉 叭 :0.9583333333333334
# 俸 叭 :0.5
# 凤 叭 :0.9230769230769231
# 佛 拔 :0.9142857142857143
# 佛 魃 :0.05714285714285714
# 否 跋 :0.8947368421052632
# 否 裨 :0.05263157894736842
# 富 魃 :0.9807692307692307
# 副 魃 :0.9782608695652174
# 福 拔 :0.02127659574468085
# 福 魃 :0.9574468085106383
# 幅 魃 :0.9411764705882353
# 辐 魃 :0.8888888888888888
# 蝠 魃 :0.5
# 匐 魃 :0.5
# 抚 魃 :0.9411764705882353
# 赴 魃 :0.9090909090909091
# 讣 魃 :0.5
# 夫 魃 :0.9885057471264368
# 扶 魃 :0.9333333333333333
# 肤 魃 :0.8333333333333334
# 呋 魃 :0.5
# 芙 魃 :0.5
# 麸 魃 :0.6666666666666666
# 负 魃 :0.975609756097561
# 复 魃 :0.9900990099009901
# 腹 魃 :0.9411764705882353
# 馥 魃 :0.5
# 覆 魃 :0.9166666666666666
# 服 魃 :0.9861111111111112
# 付 魃 :0.9655172413793104
# 府 魃 :0.9761904761904762
# 附 魃 :0.9722222222222222
# 俯 魃 :0.875
# 驸 魃 :0.5
# 符 魃 :0.9411764705882353
# 浮 魃 :0.9655172413793104
# 俘 魃 :0.8333333333333334
# 咐 魃 :0.6666666666666666
# 腑 魃 :0.5
# 孵 魃 :0.8333333333333334
# 腐 魃 :0.95
# 阜 魃 :0.75
# 妇 魃 :0.967741935483871
# 伏 魃 :0.9655172413793104
# 袱 魃 :0.6666666666666666
# 茯 魃 :0.5
# 父 魃 :0.9736842105263158
# 斧 魃 :0.8333333333333334
# 甫 魃 :0.75
# 傅 魃 :0.8333333333333334
# 辅 魃 :0.9090909090909091
# 脯 魃 :0.5
# 脯 币 :0.25
# 缚 魃 :0.6666666666666666
# 敷 魃 :0.8
# 弗 魃 :0.75
# 氟 魃 :0.8571428571428571
# 赋 魃 :0.8888888888888888
# 涪 魃 :0.5
# 嘎 茇 :0.75
# 噶 茇 :0.6666666666666666
# 伽 边 :0.5
# 咖 茇 :0.125
# 咖 蚌 :0.75
# 胳 坝 :0.6666666666666666
# 轧 茇 :0.11764705882352941
# 轧 踣 :0.058823529411764705
# 轧 睬 :0.7647058823529411
# 尬 茇 :0.5
# 夹 邦 :0.9411764705882353
# 该 霸 :0.8571428571428571
# 改 霸 :0.9833333333333333
# 盖 霸 :0.9583333333333334
# 丐 霸 :0.6666666666666666
# 钙 霸 :0.9230769230769231
# 概 霸 :0.9565217391304348
# 溉 霸 :0.8571428571428571
# 赅 霸 :0.5
# 芥 榜 :0.5
# 干 灞 :0.991304347826087
# 杆 灞 :0.9642857142857143
# 肝 灞 :0.9
# 秆 灞 :0.75
# 矸 灞 :0.5
# 酐 灞 :0.5
# 擀 灞 :0.5
# 竿 灞 :0.8888888888888888
# 敢 灞 :0.9230769230769231
# 橄 灞 :0.8333333333333334
# 赶 灞 :0.9583333333333334
# 甘 灞 :0.9642857142857143
# 柑 灞 :0.8
# 泔 灞 :0.6666666666666666
# 苷 灞 :0.5
# 感 灞 :0.9878048780487805
# 赣 灞 :0.6666666666666666
# 乾 拂 :0.75
# 尴 灞 :0.5
# 冈 罢 :0.9
# 钢 罢 :0.9868421052631579
# 刚 罢 :0.9473684210526315
# 纲 罢 :0.9545454545454546
# 岗 罢 :0.9285714285714286
# 缸 罢 :0.875
# 扛 罢 :0.3333333333333333
# 扛 胞 :0.3333333333333333
# 杠 罢 :0.8888888888888888
# 肛 罢 :0.5
# 港 罢 :0.9565217391304348
# 稿 捌 :0.96
# 高 捌 :0.9959349593495935
# 搞 捌 :0.5
# 镐 捌 :0.5
# 藁 捌 :0.5
# 告 捌 :0.9818181818181818
# 膏 捌 :0.9
# 糕 捌 :0.875
# 羔 捌 :0.75
# 皋 捌 :0.6666666666666666
# 睾 捌 :0.6666666666666666
# 个 坝 :0.9876543209876543
# 格 坝 :0.9895833333333334
# 铬 坝 :0.8571428571428571
# 各 坝 :0.9791666666666666
# 骼 坝 :0.6666666666666666
# 咯 坝 :0.5714285714285714
# 咯 蚌 :0.14285714285714285
# 咯 褙 :0.14285714285714285
# 阁 坝 :0.9166666666666666
# 搁 坝 :0.8333333333333334
# 圪 坝 :0.5
# 屹 布 :0.5
# 疙 坝 :0.5
# 隔 坝 :0.9545454545454546
# 嗝 坝 :0.5
# 哥 坝 :0.975
# 歌 坝 :0.9803921568627451
# 革 坝 :0.987012987012987
# 葛 坝 :0.8571428571428571
# 割 坝 :0.9545454545454546
# 戈 坝 :0.8888888888888888
# 合 扳 :0.9954337899543378
# 蛤 坝 :0.25
# 蛤 伴 :0.5
# 鸽 坝 :0.8333333333333334
# 颌 扳 :0.6666666666666666
# 给 白 :0.5416666666666666
# 给 扮 :0.4166666666666667
# 艮 伯 :0.5
# 根 伯 :0.9866666666666667
# 跟 伯 :0.9333333333333333
# 哏 伯 :0.5
# 亘 伯 :0.75
# 更 柏 :0.96875
# 梗 柏 :0.8333333333333334
# 埂 柏 :0.5
# 哽 柏 :0.6666666666666666
# 耕 柏 :0.9629629629629629
# 庚 柏 :0.8
# 耿 柏 :0.875
# 羹 柏 :0.8
# 颈 磅 :0.8888888888888888
# 共 百 :0.9896907216494846
# 供 百 :0.972972972972973
# 拱 百 :0.8571428571428571
# 恭 百 :0.9166666666666666
# 工 百 :0.9972602739726028
# 巩 百 :0.75
# 红 百 :0.007633587786259542
# 红 舨 :0.9847328244274809
# 贡 百 :0.875
# 汞 百 :0.75
# 攻 百 :0.96875
# 公 百 :0.9959349593495935
# 功 百 :0.9868421052631579
# 宫 百 :0.9714285714285714
# 龚 百 :0.6666666666666666
# 弓 百 :0.8333333333333334
# 躬 百 :0.75
# 蚣 百 :0.5
# 句 谤 :0.9411764705882353
# 够 佰 :0.875
# 狗 佰 :0.9090909090909091
# 佝 佰 :0.6666666666666666
# 苟 佰 :0.8571428571428571
# 枸 佰 :0.6
# 枸 谤 :0.2
# 勾 佰 :0.9090909090909091
# 构 佰 :0.975609756097561
# 购 佰 :0.9666666666666667
# 沟 佰 :0.9565217391304348
# 钩 佰 :0.8888888888888888
# 垢 佰 :0.75
# 诟 佰 :0.5
# 媾 佰 :0.6666666666666666
# 篝 佰 :0.5
# 股 捭 :0.9583333333333334
# 古 捭 :0.9911504424778761
# 故 捭 :0.9807692307692307
# 估 捭 :0.9166666666666666
# 姑 捭 :0.9523809523809523
# 沽 捭 :0.6666666666666666
# 咕 捭 :0.8571428571428571
# 蛄 捭 :0.5
# 诂 捭 :0.5
# 菇 捭 :0.75
# 轱 捭 :0.5
# 固 捭 :0.9795918367346939
# 锢 捭 :0.5
# 痼 捭 :0.5
# 梏 捭 :0.75
# 顾 捭 :0.9696969696969697
# 谷 捭 :0.9629629629629629
# 骨 捭 :0.9827586206896551
# 鼓 捭 :0.9743589743589743
# 雇 捭 :0.8888888888888888
# 辜 捭 :0.75
# 孤 捭 :0.9473684210526315
# 呱 捭 :0.5714285714285714
# 呱 稗 :0.2857142857142857
# 贾 捭 :0.2
# 贾 邦 :0.6
# 箍 捭 :0.6666666666666666
# 蛊 捭 :0.5
# 挂 稗 :0.9565217391304348
# 卦 稗 :0.75
# 褂 稗 :0.8
# 瓜 稗 :0.9565217391304348
# 刮 稗 :0.8571428571428571
# 寡 稗 :0.8571428571428571
# 括 稗 :0.2222222222222222
# 括 宝 :0.6666666666666666
# 剐 稗 :0.5
# 怪 败 :0.9473684210526315
# 拐 败 :0.8888888888888888
# 乖 败 :0.75
# 掴 败 :0.5
# 关 呗 :0.991304347826087
# 官 呗 :0.989247311827957
# 馆 呗 :0.9487179487179487
# 馆 褊 :0.02564102564102564
# 棺 呗 :0.75
# 倌 呗 :0.6666666666666666
# 管 呗 :0.9934640522875817
# 观 呗 :0.9876543209876543
# 冠 呗 :0.9473684210526315
# 灌 呗 :0.9545454545454546
# 罐 呗 :0.9230769230769231
# 贯 呗 :0.9411764705882353
# 惯 呗 :0.9375
# 掼 呗 :0.5
# 纶 钡 :0.875
# 盥 呗 :0.5
# 矜 傍 :0.6666666666666666
# 广 拜 :0.9814814814814815
# 犷 拜 :0.5
# 光 拜 :0.9951219512195122
# 胱 拜 :0.6666666666666666
# 逛 拜 :0.6666666666666666
# 贵 摆 :0.975609756097561
# 归 摆 :0.9795918367346939
# 轨 摆 :0.9444444444444444
# 圭 摆 :0.8
# 桂 摆 :0.8333333333333334
# 硅 摆 :0.9375
# 鲑 摆 :0.5
# 闺 摆 :0.6666666666666666
# 鬼 摆 :0.9629629629629629
# 傀 煲 :0.5
# 瑰 摆 :0.8
# 龟 摆 :0.7777777777777778
# 龟 浜 :0.1111111111111111
# 柜 摆 :0.9
# 规 摆 :0.9836065573770492
# 炔 煸 :0.5
# 跪 摆 :0.8
# 诡 摆 :0.875
# 癸 摆 :0.5
# 刽 摆 :0.5
# 鳜 摆 :0.5
# 滚 掰 :0.9615384615384616
# 磙 掰 :0.6666666666666666
# 棍 掰 :0.9375
# 辊 掰 :0.8
# 过 半 :0.9931972789115646
# 国 半 :0.9977324263038548
# 帼 半 :0.6666666666666666
# 蝈 半 :0.6666666666666666
# 郭 半 :0.8333333333333334
# 果 半 :0.9871794871794872
# 涡 半 :0.3333333333333333
# 涡 菠 :0.5
# 锅 半 :0.9444444444444444
# 裹 半 :0.75
# 哈 伴 :0.9807692307692307
# 虾 泊 :0.9
# 还 绊 :0.25
# 还 斑 :0.71875
# 海 绊 :0.9949238578680203
# 害 绊 :0.9782608695652174
# 孩 绊 :0.9473684210526315
# 亥 绊 :0.75
# 咳 绊 :0.25
# 咳 炮 :0.5
# 嗨 绊 :0.3333333333333333
# 嗨 坂 :0.3333333333333333
# 骇 绊 :0.75
# 嘿 绊 :0.2
# 嘿 坂 :0.6
# 骸 绊 :0.75
# 韩 拌 :0.875
# 邯 拌 :0.5
# 酣 拌 :0.6666666666666666
# 汉 拌 :0.9848484848484849
# 含 拌 :0.9583333333333334
# 喊 拌 :0.8888888888888888
# 憾 拌 :0.8
# 撼 拌 :0.75
# 寒 拌 :0.9696969696969697
# 汗 拌 :0.9333333333333333
# 鼾 拌 :0.6666666666666666
# 罕 拌 :0.8888888888888888
# 旱 拌 :0.9333333333333333
# 焊 拌 :0.9166666666666666
# 捍 拌 :0.5
# 悍 拌 :0.8
# 憨 拌 :0.6666666666666666
# 函 拌 :0.9523809523809523
# 涵 拌 :0.8888888888888888
# 翰 拌 :0.8888888888888888
# 瀚 拌 :0.6666666666666666
# 晗 拌 :0.5
# 行 版 :0.23049645390070922
# 行 播 :0.7659574468085106
# 航 版 :0.9803921568627451
# 杭 版 :0.8
# 吭 版 :0.3333333333333333
# 吭 鲍 :0.5
# 巷 箔 :0.9
# 号 板 :0.9915254237288136
# 好 板 :0.9923664122137404
# 浩 板 :0.9444444444444444
# 耗 板 :0.9583333333333334
# 郝 板 :0.6666666666666666
# 豪 板 :0.9583333333333334
# 皓 板 :0.6666666666666666
# 毫 板 :0.95
# 壕 板 :0.8
# 蚝 板 :0.5
# 嚎 板 :0.5
# 貉 扳 :0.5
# 嗥 板 :0.5
# 和 扳 :0.9534883720930233
# 和 颁 :0.03875968992248062
# 河 扳 :0.98989898989899
# 何 扳 :0.9767441860465116
# 诃 扳 :0.5
# 嗬 扳 :0.5
# 荷 扳 :0.9565217391304348
# 盒 扳 :0.8571428571428571
# 核 扳 :0.9705882352941176
# 核 搬 :0.014705882352941176
# 劾 扳 :0.5
# 阂 扳 :0.5
# 喝 扳 :0.8888888888888888
# 褐 扳 :0.8
# 鹤 扳 :0.8
# 贺 扳 :0.9444444444444444
# 赫 扳 :0.9642857142857143
# 禾 扳 :0.75
# 壑 扳 :0.5
# 涸 扳 :0.5
# 吓 扳 :0.36363636363636365
# 吓 泊 :0.5454545454545454
# 黑 坂 :0.9875
# 很 阪 :0.8571428571428571
# 恨 阪 :0.9333333333333333
# 狠 阪 :0.9230769230769231
# 痕 阪 :0.9090909090909091
# 恒 钣 :0.9166666666666666
# 横 钣 :0.972972972972973
# 亨 钣 :0.5
# 哼 钣 :0.6
# 哼 操 :0.2
# 桁 钣 :0.5
# 衡 钣 :0.9642857142857143
# 哄 舨 :0.9090909090909091
# 洪 舨 :0.9615384615384616
# 烘 舨 :0.9090909090909091
# 虹 舨 :0.9523809523809523
# 讧 舨 :0.5
# 宏 舨 :0.9090909090909091
# 鸿 舨 :0.9
# 轰 舨 :0.9090909090909091
# 弘 舨 :0.75
# 泓 舨 :0.5
# 疫 布 :0.9230769230769231
# 后 般 :0.9936305732484076
# 侯 般 :0.9
# 候 般 :0.9736842105263158
# 猴 般 :0.8
# 喉 般 :0.875
# 厚 般 :0.96875
# 吼 般 :0.75
# 户 搬 :0.98
# 护 搬 :0.9821428571428571
# 沪 搬 :0.5
# 胡 搬 :0.96875
# 湖 搬 :0.9722222222222222
# 糊 搬 :0.9545454545454546
# 瑚 搬 :0.6666666666666666
# 煳 搬 :0.5
# 蝴 搬 :0.5
# 葫 搬 :0.75
# 虎 搬 :0.967741935483871
# 唬 搬 :0.75
# 琥 搬 :0.5
# 互 搬 :0.967741935483871
# 乎 搬 :0.9523809523809523
# 呼 搬 :0.96875
# 狐 搬 :0.6666666666666666
# 弧 搬 :0.9090909090909091
# 壶 搬 :0.8
# 忽 搬 :0.9375
# 惚 搬 :0.5
# 囫 搬 :0.5
# 戏 铂 :0.9736842105263158
# 划 瘢 :0.9791666666666666
# 化 瘢 :0.9972527472527473
# 华 瘢 :0.989247311827957
# 哗 瘢 :0.8888888888888888
# 铧 瘢 :0.5
# 桦 瘢 :0.8
# 花 瘢 :0.995
# 画 瘢 :0.9864864864864865
# 话 瘢 :0.9887640449438202
# 滑 瘢 :0.975609756097561
# 猾 瘢 :0.6666666666666666
# 豁 颁 :0.8571428571428571
# 怀 绊 :0.03125
# 怀 班 :0.9375
# 坏 班 :0.9523809523809523
# 淮 班 :0.9090909090909091
# 槐 班 :0.8
# 徊 班 :0.5
# 欢 斑 :0.975
# 环 斑 :0.9841269841269841
# 换 斑 :0.9827586206896551
# 焕 斑 :0.9230769230769231
# 涣 斑 :0.5
# 唤 斑 :0.8888888888888888
# 痪 斑 :0.5
# 患 斑 :0.9375
# 桓 斑 :0.8333333333333334
# 缓 斑 :0.9583333333333334
# 幻 斑 :0.9285714285714286
# 宦 斑 :0.6666666666666666
# 豢 斑 :0.5
# 黄 癍 :0.9894736842105263
# 潢 癍 :0.5
# 璜 癍 :0.5
# 磺 癍 :0.8333333333333334
# 簧 癍 :0.8571428571428571
# 荒 癍 :0.9666666666666667
# 慌 癍 :0.9166666666666666
# 谎 癍 :0.8571428571428571
# 皇 癍 :0.972972972972973
# 煌 癍 :0.8333333333333334
# 蝗 癍 :0.5
# 惶 癍 :0.8571428571428571
# 徨 癍 :0.5
# 隍 癍 :0.75
# 凰 癍 :0.6666666666666666
# 恍 癍 :0.8
# 晃 癍 :0.95
# 幌 癍 :0.5
# 汇 办 :0.9714285714285714
# 匹 裨 :0.9285714285714286
# 会 班 :0.0028653295128939827
# 会 办 :0.9684813753581661
# 会 褓 :0.025787965616045846
# 绘 办 :0.9230769230769231
# 烩 办 :0.5
# 荟 办 :0.6666666666666666
# 回 办 :0.9918032786885246
# 洄 办 :0.75
# 蛔 办 :0.5
# 茴 办 :0.5
# 辉 办 :0.9411764705882353
# 挥 办 :0.9615384615384616
# 晖 办 :0.75
# 惠 办 :0.9545454545454546
# 蕙 办 :0.5
# 毁 办 :0.9444444444444444
# 彗 办 :0.5
# 慧 办 :0.9333333333333333
# 灰 办 :0.9782608695652174
# 恢 办 :0.8
# 诙 办 :0.5
# 悔 办 :0.9
# 晦 办 :0.75
# 诲 办 :0.6666666666666666
# 溃 办 :0.3
# 溃 煲 :0.6
# 贿 办 :0.8571428571428571
# 卉 办 :0.75
# 秽 办 :0.75
# 徽 办 :0.875
# 讳 办 :0.8333333333333334
# 喙 办 :0.5
# 混 瓣 :0.9743589743589743
# 馄 瓣 :0.6666666666666666
# 昏 瓣 :0.8888888888888888
# 婚 瓣 :0.9696969696969697
# 浑 瓣 :0.8571428571428571
# 荤 瓣 :0.5
# 诨 瓣 :0.6666666666666666
# 魂 瓣 :0.8571428571428571
# 或 颁 :0.9285714285714286
# 惑 颁 :0.9
# 活 颁 :0.99
# 获 颁 :0.96
# 货 颁 :0.9879518072289156
# 火 颁 :0.99375
# 伙 颁 :0.9411764705882353
# 霍 颁 :0.9230769230769231
# 嚯 颁 :0.5
# 攉 颁 :0.5
# 祸 颁 :0.9285714285714286
# 几 扮 :0.9807692307692307
# 机 扮 :0.9971098265895953
# 饥 扮 :0.9090909090909091
# 矶 扮 :0.6666666666666666
# 叽 扮 :0.6666666666666666
# 肌 扮 :0.875
# 讥 扮 :0.75
# 及 扮 :0.967741935483871
# 圾 扮 :0.8333333333333334
# 极 扮 :0.9866666666666667
# 汲 扮 :0.5
# 级 扮 :0.9907407407407407
# 己 扮 :0.9545454545454546
# 记 扮 :0.9850746268656716
# 纪 扮 :0.984375
# 鸡 扮 :0.9583333333333334
# 基 扮 :0.9923076923076923
# 计 扮 :0.9913793103448276
# 集 扮 :0.9895833333333334
# 际 扮 :0.9838709677419355
# 齐 逼 :0.9642857142857143
# 济 扮 :0.9886363636363636
# 挤 扮 :0.9
# 剂 扮 :0.9807692307692307
# 跻 扮 :0.6666666666666666
# 荠 扮 :0.5
# 吉 扮 :0.9736842105263158
# 咭 扮 :0.5
# 继 扮 :0.9696969696969697
# 系 扮 :0.021739130434782608
# 系 铂 :0.967391304347826
# 急 扮 :0.9818181818181818
# 积 扮 :0.9868421052631579
# 季 扮 :0.96
# 悸 扮 :0.5
# 籍 扮 :0.9444444444444444
# 藉 扮 :0.8
# 技 扮 :0.98
# 伎 扮 :0.6666666666666666
# 妓 扮 :0.8
# 击 扮 :0.9850746268656716
# 暨 扮 :0.5
# 绩 扮 :0.9
# 姬 扮 :0.6666666666666666
# 箕 扮 :0.6666666666666666
# 稽 扮 :0.8333333333333334
# 蓟 扮 :0.5
# 寄 扮 :0.9444444444444444
# 奇 扮 :0.05263157894736842
# 奇 逼 :0.9210526315789473
# 畸 扮 :0.6666666666666666
# 迹 扮 :0.96875
# 疾 扮 :0.9333333333333333
# 忌 扮 :0.875
# 激 扮 :0.9761904761904762
# 祭 扮 :0.9
# 辑 扮 :0.9333333333333333
# 缉 扮 :0.6666666666666666
# 缉 逼 :0.16666666666666666
# 寂 扮 :0.8888888888888888
# 脊 扮 :0.9285714285714286
# 瘠 扮 :0.6666666666666666
# 期 逼 :0.991869918699187
# 稷 扮 :0.6666666666666666
# 棘 扮 :0.8333333333333334
# 鲫 扮 :0.5
# 羁 扮 :0.75
# 戟 扮 :0.5
# 其 扮 :0.021739130434782608
# 其 逼 :0.9565217391304348
# 亟 扮 :0.75
# 觊 扮 :0.5
# 即 扮 :0.9629629629629629
# 既 扮 :0.9090909090909091
# 唧 扮 :0.75
# 畿 扮 :0.5
# 嫉 扮 :0.5
# 家 邦 :0.9967105263157895
# 嫁 邦 :0.875
# 稼 邦 :0.8
# 嘉 邦 :0.9583333333333334
# 价 邦 :0.9807692307692307
# 价 榜 :0.009615384615384616
# 加 邦 :0.9936305732484076
# 枷 邦 :0.5
# 架 邦 :0.975
# 驾 邦 :0.9285714285714286
# 假 邦 :0.9811320754716981
# 茄 邦 :0.42857142857142855
# 茄 边 :0.42857142857142855
# 袈 邦 :0.5
# 迦 邦 :0.6666666666666666
# 佳 邦 :0.9444444444444444
# 甲 邦 :0.9767441860465116
# 钾 邦 :0.9333333333333333
# 胛 邦 :0.5
# 浃 邦 :0.5
# 颊 邦 :0.6666666666666666
# 荚 邦 :0.6666666666666666
# 件 绑 :0.9852941176470589
# 建 绑 :0.9903846153846154
# 健 绑 :0.96875
# 键 绑 :0.9375
# 毽 绑 :0.5
# 间 绑 :0.9888888888888889
# 涧 绑 :0.5
# 简 绑 :0.9791666666666666
# 见 绑 :0.9895833333333334
# 舰 绑 :0.95
# 减 绑 :0.9761904761904762
# 碱 绑 :0.9642857142857143
# 缄 绑 :0.5
# 兼 绑 :0.9285714285714286
# 蒹 绑 :0.5
# 检 绑 :0.9761904761904762
# 剑 绑 :0.9285714285714286
# 捡 绑 :0.5
# 俭 绑 :0.875
# 睑 绑 :0.5
# 肩 绑 :0.9090909090909091
# 监 绑 :0.9642857142857143
# 槛 刨 :0.75
# 尖 绑 :0.9629629629629629
# 坚 绑 :0.967741935483871
# 菅 绑 :0.5
# 渐 绑 :0.9230769230769231
# 鉴 绑 :0.9166666666666666
# 剪 绑 :0.9523809523809523
# 箭 绑 :0.9285714285714286
# 煎 绑 :0.75
# 拣 绑 :0.5
# 歼 绑 :0.8333333333333334
# 茧 绑 :0.8571428571428571
# 荐 绑 :0.875
# 柬 绑 :0.5
# 戋 绑 :0.6666666666666666
# 浅 拂 :0.9545454545454546
# 饯 绑 :0.75
# 贱 绑 :0.8571428571428571
# 践 绑 :0.9
# 溅 绑 :0.75
# 笺 绑 :0.5
# 奸 绑 :0.9166666666666666
# 艰 绑 :0.9285714285714286
# 江 梆 :0.9885057471264368
# 豇 梆 :0.5
# 将 梆 :0.9795918367346939
# 奖 梆 :0.9666666666666667
# 浆 梆 :0.9642857142857143
# 桨 梆 :0.75
# 酱 梆 :0.8571428571428571
# 蒋 梆 :0.75
# 强 梆 :0.03488372093023256
# 强 愎 :0.9534883720930233
# 糨 梆 :0.5
# 犟 梆 :0.6666666666666666
# 降 梆 :0.7894736842105263
# 降 箔 :0.18421052631578946
# 绛 梆 :0.5
# 讲 梆 :0.9782608695652174
# 姜 梆 :0.75
# 疆 梆 :0.9090909090909091
# 僵 梆 :0.9
# 缰 梆 :0.5
# 匠 梆 :0.9230769230769231
# 交 帮 :0.9934640522875817
# 较 帮 :0.8333333333333334
# 胶 帮 :0.9782608695652174
# 蛟 帮 :0.5
# 绞 帮 :0.9
# 郊 帮 :0.9411764705882353
# 跤 帮 :0.5
# 饺 帮 :0.75
# 狡 帮 :0.8
# 铰 帮 :0.8
# 校 帮 :0.058823529411764705
# 校 博 :0.9215686274509803
# 侥 帮 :0.5
# 浇 帮 :0.9
# 叫 帮 :0.9523809523809523
# 教 帮 :0.9924812030075187
# 脚 邦 :0.038461538461538464
# 脚 帮 :0.9423076923076923
# 缴 帮 :0.9166666666666666
# 角 邦 :0.025423728813559324
# 角 帮 :0.8898305084745762
# 角 棒 :0.07627118644067797
# 焦 帮 :0.9583333333333334
# 礁 帮 :0.8
# 蕉 帮 :0.6666666666666666
# 觉 帮 :0.1
# 觉 棒 :0.8666666666666667
# 搅 帮 :0.875
# 矫 帮 :0.875
# 娇 帮 :0.8
# 轿 帮 :0.8571428571428571
# 骄 帮 :0.8571428571428571
# 窖 帮 :0.8
# 椒 帮 :0.8333333333333334
# 嚼 帮 :0.25
# 嚼 棒 :0.5
# 酵 帮 :0.8888888888888888
# 届 榜 :0.9
# 节 榜 :0.9908256880733946
# 借 榜 :0.9655172413793104
# 街 榜 :0.9523809523809523
# 杰 榜 :0.95
# 接 榜 :0.989247311827957
# 解 榜 :0.9711538461538461
# 解 膊 :0.019230769230769232
# 结 榜 :0.9912280701754386
# 洁 榜 :0.9333333333333333
# 秸 榜 :0.5
# 桔 谤 :0.875
# 拮 榜 :0.5
# 皆 榜 :0.8333333333333334
# 楷 包 :0.6666666666666666
# 戒 榜 :0.9375
# 截 榜 :0.95
# 诫 榜 :0.6666666666666666
# 捷 榜 :0.9473684210526315
# 睫 榜 :0.6666666666666666
# 揭 榜 :0.9230769230769231
# 竭 榜 :0.9
# 阶 榜 :0.9836065573770492
# 介 榜 :0.95
# 界 榜 :0.9888888888888889
# 姐 榜 :0.9333333333333333
# 劫 榜 :0.9090909090909091
# 金 傍 :0.9953051643192489
# 仅 傍 :0.8888888888888888
# 进 傍 :0.9906542056074766
# 尽 傍 :0.9818181818181818
# 烬 傍 :0.6666666666666666
# 荩 傍 :0.5
# 锦 傍 :0.9473684210526315
# 津 傍 :0.9166666666666666
# 斤 傍 :0.8571428571428571
# 近 傍 :0.9836065573770492
# 晋 傍 :0.9285714285714286
# 今 傍 :0.975
# 劲 傍 :0.7241379310344828
# 劲 磅 :0.2413793103448276
# 紧 傍 :0.975
# 禁 傍 :0.9629629629629629
# 襟 傍 :0.8
# 噤 傍 :0.5
# 巾 傍 :0.9333333333333333
# 浸 傍 :0.9166666666666666
# 谨 傍 :0.875
# 馑 傍 :0.5
# 筋 傍 :0.9285714285714286
# 觐 傍 :0.5
# 竞 磅 :0.9565217391304348
# 竟 磅 :0.9285714285714286
# 境 磅 :0.9791666666666666
# 镜 磅 :0.9705882352941176
# 经 磅 :0.994413407821229
# 径 磅 :0.9666666666666667
# 茎 磅 :0.8333333333333334
# 痉 磅 :0.5
# 井 磅 :0.9791666666666666
# 阱 磅 :0.5
# 精 磅 :0.9905660377358491
# 靖 磅 :0.8333333333333334
# 腈 磅 :0.6666666666666666
# 睛 磅 :0.75
# 靓 焙 :0.5
# 静 磅 :0.9811320754716981
# 菁 磅 :0.6666666666666666
# 净 磅 :0.9444444444444444
# 景 磅 :0.975
# 憬 磅 :0.5
# 京 磅 :0.9827586206896551
# 惊 磅 :0.9696969696969697
# 鲸 磅 :0.8333333333333334
# 敬 磅 :0.9642857142857143
# 警 磅 :0.9761904761904762
# 荆 磅 :0.8571428571428571
# 晶 磅 :0.9736842105263158
# 兢 磅 :0.6666666666666666
# 儆 磅 :0.5
# 旌 磅 :0.5
# 粳 磅 :0.5
# 窘 膀 :0.75
# 迥 膀 :0.6666666666666666
# 炯 膀 :0.8333333333333334
# 就 镑 :0.9761904761904762
# 纠 镑 :0.8571428571428571
# 赳 镑 :0.6666666666666666
# 九 镑 :0.9921875
# 旧 镑 :0.9772727272727273
# 酒 镑 :0.9824561403508771
# 久 镑 :0.96875
# 疚 镑 :0.5
# 玖 镑 :0.5
# 救 镑 :0.9761904761904762
# 究 镑 :0.96
# 柩 镑 :0.5
# 灸 镑 :0.5
# 揪 镑 :0.5
# 臼 镑 :0.5
# 桕 镑 :0.5
# 舅 镑 :0.9444444444444444
# 咎 镑 :0.8
# 鹫 镑 :0.5
# 鸠 镑 :0.6666666666666666
# 厩 镑 :0.5
# 韭 镑 :0.6666666666666666
# 阄 镑 :0.5
# 局 谤 :0.9871794871794872
# 居 谤 :0.9777777777777777
# 据 谤 :0.96875
# 踞 谤 :0.5
# 锯 谤 :0.875
# 巨 谤 :0.9333333333333333
# 拒 谤 :0.8333333333333334
# 距 谤 :0.9444444444444444
# 炬 谤 :0.8333333333333334
# 矩 谤 :0.9230769230769231
# 苣 谤 :0.5
# 驹 谤 :0.6666666666666666
# 拘 谤 :0.9166666666666666
# 具 谤 :0.9777777777777777
# 俱 谤 :0.8571428571428571
# 惧 谤 :0.875
# 飓 谤 :0.5
# 举 谤 :0.984375
# 剧 谤 :0.9795918367346939
# 聚 谤 :0.9821428571428571
# 菊 谤 :0.8
# 鞠 谤 :0.6666666666666666
# 掬 谤 :0.6666666666666666
# 且 谤 :0.09090909090909091
# 且 边 :0.8181818181818182
# 咀 谤 :0.6666666666666666
# 龃 谤 :0.5
# 沮 谤 :0.5
# 疽 谤 :0.5
# 遽 谤 :0.5
# 橘 谤 :0.75
# 卷 蒡 :0.9705882352941176
# 倦 蒡 :0.8333333333333334
# 圈 蒡 :0.3225806451612903
# 圈 褊 :0.6451612903225806
# 眷 蒡 :0.8333333333333334
# 捐 蒡 :0.9333333333333333
# 娟 蒡 :0.6666666666666666
# 绢 蒡 :0.6666666666666666
# 涓 蒡 :0.75
# 隽 浜 :0.5
# 镌 蒡 :0.5
# 俊 蒡 :0.14285714285714285
# 俊 浜 :0.7142857142857143
# 鹃 蒡 :0.6666666666666666
# 决 棒 :0.9827586206896551
# 诀 棒 :0.75
# 抉 棒 :0.5
# 绝 棒 :0.9814814814814815
# 掘 棒 :0.8888888888888888
# 倔 棒 :0.6666666666666666
# 崛 棒 :0.5
# 爵 棒 :0.875
# 厥 棒 :0.5
# 撅 棒 :0.5
# 镢 棒 :0.5
# 蹶 棒 :0.5
# 獗 棒 :0.5
# 噱 钹 :0.5
# 攫 棒 :0.6666666666666666
# 钧 浜 :0.6666666666666666
# 均 浜 :0.9642857142857143
# 军 浜 :0.9953271028037384
# 峻 浜 :0.875
# 骏 浜 :0.75
# 浚 浜 :0.8
# 竣 浜 :0.5
# 君 浜 :0.9615384615384616
# 郡 浜 :0.6666666666666666
# 菌 浜 :0.9714285714285714
# 卡 蚌 :0.9473684210526315
# 卡 苞 :0.017543859649122806
# 卡 彼 :0.017543859649122806
# 咔 蚌 :0.5
# 喀 蚌 :0.9166666666666666
# 开 包 :0.9951923076923077
# 凯 包 :0.9230769230769231
# 恺 包 :0.5
# 揩 包 :0.5
# 慨 包 :0.9
# 考 饱 :0.9811320754716981
# 烤 饱 :0.9
# 铐 饱 :0.75
# 拷 饱 :0.75
# 靠 饱 :0.9523809523809523
# 犒 饱 :0.5
# 坎 刨 :0.8
# 砍 刨 :0.8
# 嵌 拂 :0.6666666666666666
# 看 刨 :0.9855072463768116
# 刊 刨 :0.9696969696969697
# 侃 刨 :0.8333333333333334
# 堪 刨 :0.9
# 勘 刨 :0.875
# 瞰 刨 :0.6666666666666666
# 龛 刨 :0.5
# 戡 刨 :0.5
# 亢 胞 :0.75
# 炕 胞 :0.8571428571428571
# 抗 胞 :0.9814814814814815
# 糠 胞 :0.8
# 慷 胞 :0.75
# 康 胞 :0.9666666666666667
# 可 炮 :0.9927007299270073
# 柯 炮 :0.75
# 坷 炮 :0.5
# 轲 炮 :0.5
# 苛 炮 :0.875
# 克 炮 :0.9916666666666667
# 科 炮 :0.990990990990991
# 客 炮 :0.984375
# 颗 炮 :0.75
# 棵 炮 :0.5
# 课 炮 :0.9736842105263158
# 稞 炮 :0.5
# 刻 炮 :0.975609756097561
# 颏 炮 :0.5
# 磕 炮 :0.6666666666666666
# 瞌 炮 :0.6666666666666666
# 壳 炮 :0.8461538461538461
# 壳 鄙 :0.07692307692307693
# 渴 炮 :0.8888888888888888
# 恪 炮 :0.5
# 肯 苞 :0.9090909090909091
# 啃 苞 :0.6666666666666666
# 垦 苞 :0.9090909090909091
# 恳 苞 :0.875
# 坑 鲍 :0.9090909090909091
# 铿 鲍 :0.6666666666666666
# 空 龅 :0.9927007299270073
# 控 龅 :0.9615384615384616
# 孔 龅 :0.9705882352941176
# 恐 龅 :0.9523809523809523
# 口 雹 :0.9948453608247423
# 扣 雹 :0.9473684210526315
# 筘 雹 :0.5
# 叩 雹 :0.75
# 寇 雹 :0.8
# 蔻 雹 :0.5
# 抠 雹 :0.6666666666666666
# 眍 雹 :0.5
# 库 报 :0.975609756097561
# 裤 报 :0.9333333333333333
# 枯 报 :0.9375
# 酷 报 :0.9
# 骷 报 :0.5
# 苦 报 :0.9857142857142858
# 哭 报 :0.9
# 窟 报 :0.8571428571428571
# 夸 保 :0.9285714285714286
# 挎 保 :0.75
# 跨 保 :0.9090909090909091
# 垮 保 :0.6666666666666666
# 侉 保 :0.5
# 筷 褓 :0.6666666666666666
# 快 褓 :0.9827586206896551
# 块 褓 :0.9583333333333334
# 侩 褓 :0.5
# 脍 褓 :0.6666666666666666
# 款 葆 :0.9821428571428571
# 宽 葆 :0.95
# 矿 堡 :0.9878048780487805
# 旷 堡 :0.8571428571428571
# 匡 堡 :0.8
# 框 堡 :0.9444444444444444
# 眶 堡 :0.75
# 哐 堡 :0.5
# 诓 堡 :0.5
# 筐 堡 :0.75
# 狂 堡 :0.95
# 况 堡 :0.96
# 亏 煲 :0.9285714285714286
# 奎 煲 :0.6666666666666666
# 愧 煲 :0.8888888888888888
# 魁 煲 :0.875
# 睽 煲 :0.6666666666666666
# 葵 煲 :0.6666666666666666
# 馈 煲 :0.75
# 篑 煲 :0.5
# 匮 煲 :0.6666666666666666
# 窥 煲 :0.75
# 盔 煲 :0.8
# 困 褒 :0.9444444444444444
# 捆 褒 :0.6666666666666666
# 昆 褒 :0.9090909090909091
# 锟 褒 :0.5
# 坤 褒 :0.6666666666666666
# 栝 稗 :0.5
# 适 滨 :0.9545454545454546
# 阔 宝 :0.9333333333333333
# 扩 宝 :0.9523809523809523
# 廓 宝 :0.5
# 拉 薄 :0.9934640522875817
# 垃 薄 :0.8333333333333334
# 啦 薄 :0.9230769230769231
# 喇 薄 :0.8571428571428571
# 腊 薄 :0.9166666666666666
# 蜡 薄 :0.9230769230769231
# 落 薄 :0.02040816326530612
# 落 剥 :0.030612244897959183
# 落 辈 :0.9387755102040817
# 辣 薄 :0.9090909090909091
# 来 豹 :0.9940476190476191
# 莱 豹 :0.9411764705882353
# 睐 豹 :0.5
# 徕 豹 :0.5
# 赖 豹 :0.9333333333333333
# 濑 豹 :0.5
# 籁 豹 :0.5
# 癞 豹 :0.5
# 兰 暴 :0.9726027397260274
# 兰 鐾 :0.0136986301369863
# 栏 暴 :0.9166666666666666
# 烂 暴 :0.9444444444444444
# 拦 暴 :0.9166666666666666
# 蓝 暴 :0.96875
# 滥 暴 :0.9090909090909091
# 篮 暴 :0.9230769230769231
# 褴 暴 :0.5
# 岚 暴 :0.6666666666666666
# 览 暴 :0.9411764705882353
# 揽 暴 :0.8888888888888888
# 缆 暴 :0.8333333333333334
# 榄 暴 :0.8333333333333334
# 阑 暴 :0.5
# 斓 暴 :0.5
# 懒 暴 :0.875
# 婪 暴 :0.5
# 狼 爆 :0.9090909090909091
# 浪 爆 :0.9642857142857143
# 郎 爆 :0.9166666666666666
# 朗 爆 :0.9583333333333334
# 琅 爆 :0.75
# 锒 爆 :0.5
# 榔 爆 :0.6666666666666666
# 廊 爆 :0.8333333333333334
# 老 剥 :0.9940119760479041
# 姥 剥 :0.75
# 佬 剥 :0.5
# 劳 剥 :0.9901960784313726
# 捞 剥 :0.8333333333333334
# 涝 剥 :0.9
# 唠 剥 :0.6666666666666666
# 痨 剥 :0.5
# 牢 剥 :0.9375
# 烙 剥 :0.6
# 烙 辈 :0.2
# 络 辈 :0.9230769230769231
# 酪 剥 :0.8333333333333334
# 了 趵 :0.2727272727272727
# 了 碚 :0.7045454545454546
# 叻 趵 :0.5
# 肋 鸨 :0.75
# 勒 趵 :0.8780487804878049
# 勒 鸨 :0.07317073170731707
# 勒 婊 :0.024390243902439025
# 乐 趵 :0.42
# 乐 埔 :0.57
# 垒 鸨 :0.9090909090909091
# 类 鸨 :0.9827586206896551
# 雷 鸨 :0.9787234042553191
# 蕾 鸨 :0.875
# 擂 鸨 :0.6666666666666666
# 镭 鸨 :0.6666666666666666
# 累 鸨 :0.96
# 嘞 鸨 :0.5
# 泪 鸨 :0.9411764705882353
# 磊 鸨 :0.5
# 儡 鸨 :0.5
# 愣 被 :0.6666666666666666
# 楞 被 :0.5
# 棱 被 :0.9090909090909091
# 冷 被 :0.9814814814814815
# 丽 陂 :0.9565217391304348
# 鲡 陂 :0.5
# 厉 陂 :0.9
# 励 陂 :0.8888888888888888
# 雳 陂 :0.5
# 砺 陂 :0.5
# 力 陂 :0.9967105263157895
# 历 陂 :0.9818181818181818
# 沥 陂 :0.8333333333333334
# 砾 陂 :0.8
# 里 陂 :0.9923664122137404
# 理 陂 :0.9952153110047847
# 哩 陂 :0.75
# 喱 陂 :0.5
# 狸 陂 :0.5
# 鲤 陂 :0.5
# 厘 陂 :0.75
# 娌 陂 :0.5
# 李 陂 :0.9565217391304348
# 利 陂 :0.9947916666666666
# 俐 陂 :0.5
# 猁 陂 :0.5
# 梨 陂 :0.875
# 犁 陂 :0.8888888888888888
# 莉 陂 :0.8888888888888888
# 痢 陂 :0.6666666666666666
# 立 陂 :0.9924242424242424
# 粒 陂 :0.96
# 笠 陂 :0.5
# 离 陂 :0.9855072463768116
# 漓 陂 :0.75
# 璃 陂 :0.9444444444444444
# 篱 陂 :0.75
# 礼 陂 :0.9861111111111112
# 黎 陂 :0.9
# 藜 陂 :0.6666666666666666
# 例 陂 :0.9761904761904762
# 栗 陂 :0.8571428571428571
# 溧 陂 :0.6666666666666666
# 傈 陂 :0.5
# 荔 陂 :0.5
# 澧 陂 :0.5
# 罹 陂 :0.5
# 吏 陂 :0.8888888888888888
# 隶 陂 :0.9230769230769231
# 戾 陂 :0.5
# 联 倍 :0.9886363636363636
# 连 倍 :0.9866666666666667
# 莲 倍 :0.9
# 链 倍 :0.9375
# 鲢 倍 :0.6666666666666666
# 练 倍 :0.9714285714285714
# 炼 倍 :0.9523809523809523
# 脸 倍 :0.96
# 殓 倍 :0.5
# 敛 倍 :0.8333333333333334
# 帘 倍 :0.875
# 怜 倍 :0.8
# 廉 倍 :0.9230769230769231
# 镰 倍 :0.6666666666666666
# 恋 倍 :0.9166666666666666
# 两 焙 :0.9855072463768116
# 辆 焙 :0.8333333333333334
# 俩 焙 :0.4
# 俩 艚 :0.5
# 量 焙 :0.9939024390243902
# 良 焙 :0.9761904761904762
# 粮 焙 :0.9666666666666667
# 踉 焙 :0.5
# 梁 焙 :0.9583333333333334
# 粱 焙 :0.6666666666666666
# 亮 焙 :0.9615384615384616
# 凉 焙 :0.95
# 晾 焙 :0.75
# 谅 焙 :0.8
# 辽 碚 :0.9090909090909091
# 疗 碚 :0.9545454545454546
# 料 碚 :0.992
# 寥 碚 :0.8333333333333334
# 廖 碚 :0.5
# 聊 碚 :0.9090909090909091
# 撂 碚 :0.6666666666666666
# 撩 碚 :0.75
# 僚 碚 :0.875
# 燎 碚 :0.6666666666666666
# 镣 碚 :0.6666666666666666
# 缭 碚 :0.75
# 嘹 碚 :0.5
# 猎 蓓 :0.9090909090909091
# 列 蓓 :0.9838709677419355
# 咧 蓓 :0.6666666666666666
# 冽 蓓 :0.5
# 烈 蓓 :0.967741935483871
# 裂 蓓 :0.9714285714285714
# 劣 蓓 :0.9230769230769231
# 林 北 :0.9935064935064936
# 琳 北 :0.8333333333333334
# 淋 北 :0.9333333333333333
# 霖 北 :0.5
# 临 北 :0.9782608695652174
# 鳞 北 :0.8
# 麟 北 :0.75
# 磷 北 :0.9375
# 粼 北 :0.6666666666666666
# 遴 北 :0.5
# 邻 北 :0.9411764705882353
# 吝 北 :0.5
# 赁 北 :0.6666666666666666
# 廪 北 :0.5
# 檩 北 :0.5
# 凛 北 :0.8571428571428571
# 躏 北 :0.5
# 拎 邶 :0.5
# 令 邶 :0.9824561403508771
# 岭 邶 :0.9473684210526315
# 领 邶 :0.9863013698630136
# 龄 邶 :0.9583333333333334
# 铃 邶 :0.9166666666666666
# 玲 邶 :0.875
# 伶 邶 :0.5
# 羚 邶 :0.5
# 聆 邶 :0.6666666666666666
# 翎 邶 :0.5
# 苓 邶 :0.5
# 零 邶 :0.975
# 灵 邶 :0.96875
# 另 邶 :0.8
# 陵 邶 :0.96
# 菱 邶 :0.75
# 凌 邶 :0.9230769230769231
# 绫 邶 :0.5
# 鲮 邶 :0.5
# 刘 背 :0.9
# 浏 背 :0.6666666666666666
# 六 背 :0.96875
# 六 贝 :0.015625
# 留 背 :0.9814814814814815
# 溜 背 :0.8888888888888888
# 榴 背 :0.8
# 熘 背 :0.5
# 馏 背 :0.8888888888888888
# 瘤 背 :0.9
# 遛 背 :0.6666666666666666
# 流 背 :0.9951923076923077
# 硫 背 :0.9705882352941176
# 琉 背 :0.8571428571428571
# 柳 背 :0.9545454545454546
# 陆 背 :0.030303030303030304
# 陆 贝 :0.9393939393939394
# 绺 背 :0.5
# 碌 贝 :0.8333333333333334
# 龙 臂 :0.9866666666666667
# 拢 臂 :0.875
# 胧 臂 :0.5
# 珑 臂 :0.6666666666666666
# 咙 臂 :0.5
# 茏 臂 :0.5
# 笼 臂 :0.9444444444444444
# 垄 臂 :0.9166666666666666
# 聋 臂 :0.8571428571428571
# 隆 臂 :0.9523809523809523
# 窿 臂 :0.5
# 弄 臂 :0.09090909090909091
# 弄 必 :0.8636363636363636
# 楼 杯 :0.9722222222222222
# 搂 杯 :0.6666666666666666
# 髅 杯 :0.5
# 偻 杯 :0.6666666666666666
# 蝼 杯 :0.5
# 篓 杯 :0.75
# 漏 杯 :0.9545454545454546
# 陋 杯 :0.8333333333333334
# 露 杯 :0.125
# 露 贝 :0.85
# 路 贝 :0.9939759036144579
# 鹭 贝 :0.5
# 卢 贝 :0.9166666666666666
# 泸 贝 :0.6666666666666666
# 炉 贝 :0.9791666666666666
# 鲈 贝 :0.5
# 胪 贝 :0.5
# 颅 贝 :0.75
# 轳 贝 :0.5
# 驴 槽 :0.6666666666666666
# 庐 贝 :0.8
# 芦 贝 :0.9166666666666666
# 卤 贝 :0.8888888888888888
# 录 贝 :0.9811320754716981
# 绿 贝 :0.17777777777777778
# 绿 槽 :0.8
# 禄 贝 :0.875
# 鲁 贝 :0.9629629629629629
# 氇 贝 :0.5
# 鹿 贝 :0.9
# 麓 贝 :0.5
# 辘 贝 :0.6666666666666666
# 漉 贝 :0.6666666666666666
# 戮 贝 :0.6666666666666666
# 虏 贝 :0.5
# 赂 贝 :0.6666666666666666
# 滦 狈 :0.6666666666666666
# 峦 狈 :0.6666666666666666
# 孪 狈 :0.5
# 挛 狈 :0.5
# 乱 狈 :0.9811320754716981
# 卵 狈 :0.9565217391304348
# 仑 钡 :0.8
# 轮 钡 :0.9875
# 论 钡 :0.9907407407407407
# 伦 钡 :0.96875
# 抡 钡 :0.5
# 沦 钡 :0.75
# 囵 钡 :0.5
# 罗 辈 :0.9886363636363636
# 锣 辈 :0.75
# 萝 辈 :0.8
# 箩 辈 :0.6666666666666666
# 逻 辈 :0.9166666666666666
# 洛 辈 :0.9666666666666667
# 骆 辈 :0.6666666666666666
# 螺 辈 :0.95
# 骡 辈 :0.75
# 裸 辈 :0.8571428571428571
# 荦 辈 :0.5
# 律 槽 :0.9846153846153847
# 率 槟 :0.12903225806451613
# 率 槽 :0.8602150537634409
# 氯 槽 :0.9666666666666667
# 吕 槽 :0.8333333333333334
# 侣 槽 :0.75
# 铝 槽 :0.8888888888888888
# 旅 槽 :0.9705882352941176
# 虑 槽 :0.9230769230769231
# 履 槽 :0.8888888888888888
# 缕 槽 :0.8
# 褛 槽 :0.5
# 屡 槽 :0.8571428571428571
# 捋 槽 :0.5
# 略 草 :0.9761904761904762
# 掠 草 :0.8571428571428571
# 马 辈 :0.0056179775280898875
# 马 碑 :0.9887640449438202
# 吗 碑 :0.8571428571428571
# 蚂 碑 :0.6666666666666666
# 玛 碑 :0.8888888888888888
# 码 碑 :0.9444444444444444
# 妈 碑 :0.96
# 骂 碑 :0.9285714285714286
# 麻 碑 :0.9807692307692307
# 嘛 碑 :0.8333333333333334
# 摩 畚 :0.967741935483871
# 嬷 碑 :0.6666666666666666
# 蟆 碑 :0.6666666666666666
# 么 碑 :0.19230769230769232
# 么 惫 :0.7692307692307693
# 抹 碑 :0.2
# 抹 畚 :0.7
# 呒 策 :0.5
# 买 萆 :0.9259259259259259
# 买 鞴 :0.037037037037037035
# 卖 萆 :0.9705882352941176
# 麦 萆 :0.972972972972973
# 迈 萆 :0.9
# 劢 萆 :0.5
# 埋 萆 :0.8181818181818182
# 埋 鹎 :0.09090909090909091
# 霾 萆 :0.5
# 脉 萆 :0.918918918918919
# 脉 畚 :0.05405405405405406
# 毛 悖 :0.9893617021276596
# 牦 悖 :0.5
# 髦 悖 :0.5
# 贸 悖 :0.9743589743589743
# 锚 悖 :0.8571428571428571
# 猫 悖 :0.75
# 茂 悖 :0.9
# 冒 悖 :0.95
# 帽 悖 :0.9166666666666666
# 瑁 悖 :0.5
# 矛 悖 :0.9375
# 茅 悖 :0.9090909090909091
# 卯 悖 :0.5
# 铆 悖 :0.5
# 茆 悖 :0.5
# 貌 悖 :0.9411764705882353
# 曼 鹎 :0.9411764705882353
# 慢 鹎 :0.9523809523809523
# 漫 鹎 :0.9545454545454546
# 鳗 鹎 :0.75
# 幔 鹎 :0.6666666666666666
# 馒 鹎 :0.5
# 谩 鹎 :0.5
# 蔓 鹎 :0.6666666666666666
# 满 鹎 :0.9836065573770492
# 瞒 鹎 :0.6666666666666666
# 蛮 鹎 :0.875
# 忙 备 :0.9615384615384616
# 氓 备 :0.5
# 芒 备 :0.8571428571428571
# 茫 备 :0.8888888888888888
# 莽 备 :0.8571428571428571
# 盲 备 :0.9230769230769231
# 每 鞴 :0.9166666666666666
# 梅 鞴 :0.967741935483871
# 酶 鞴 :0.8571428571428571
# 莓 鞴 :0.6666666666666666
# 霉 鞴 :0.9285714285714286
# 没 鞴 :0.725
# 没 畚 :0.25
# 美 鞴 :0.9894736842105263
# 镁 鞴 :0.9
# 煤 鞴 :0.9736842105263158
# 媒 鞴 :0.8888888888888888
# 枚 鞴 :0.6666666666666666
# 妹 鞴 :0.9583333333333334
# 昧 鞴 :0.8888888888888888
# 魅 鞴 :0.6666666666666666
# 眉 鞴 :0.9583333333333334
# 湄 鞴 :0.5
# 媚 鞴 :0.8888888888888888
# 楣 鞴 :0.75
# 嵋 鞴 :0.5
# 玫 鞴 :0.8333333333333334
# 寐 鞴 :0.6666666666666666
# 袂 鞴 :0.5
# 糜 苯 :0.5
# 谜 苯 :0.8888888888888888
# 浼 鞴 :0.5
# 门 鐾 :0.9942857142857143
# 们 鐾 :0.9523809523809523
# 闷 鐾 :0.9166666666666666
# 焖 鐾 :0.5
# 懑 鐾 :0.5
# 孟 本 :0.9230769230769231
# 猛 本 :0.96
# 锰 本 :0.8333333333333334
# 梦 本 :0.9411764705882353
# 蒙 本 :0.9722222222222222
# 檬 本 :0.5
# 朦 本 :0.5
# 盟 本 :0.9629629629629629
# 萌 本 :0.8333333333333334
# 米 苯 :0.9827586206896551
# 迷 苯 :0.9655172413793104
# 咪 苯 :0.6666666666666666
# 眯 苯 :0.8333333333333334
# 醚 苯 :0.6666666666666666
# 麋 苯 :0.5
# 泌 苯 :0.8
# 密 苯 :0.9850746268656716
# 蜜 苯 :0.9090909090909091
# 弥 苯 :0.8888888888888888
# 靡 苯 :0.75
# 觅 苯 :0.6666666666666666
# 苗 笨 :0.9767441860465116
# 瞄 笨 :0.6666666666666666
# 描 笨 :0.9090909090909091
# 喵 笨 :0.5
# 庙 笨 :0.9333333333333333
# 秒 笨 :0.875
# 妙 笨 :0.9411764705882353
# 眇 笨 :0.5
# 渺 笨 :0.75
# 藐 笨 :0.5
# 面 奔 :0.9957081545064378
# 缅 奔 :0.8
# 腼 奔 :0.5
# 棉 奔 :0.9743589743589743
# 绵 奔 :0.9333333333333333
# 免 奔 :0.96
# 勉 奔 :0.75
# 娩 奔 :0.6666666666666666
# 冕 奔 :0.75
# 眠 奔 :0.875
# 灭 贲 :0.9565217391304348
# 蔑 贲 :0.8
# 篾 贲 :0.5
# 咩 贲 :0.5
# 民 锛 :0.9964664310954063
# 泯 锛 :0.5
# 岷 锛 :0.5
# 抿 锛 :0.5
# 敏 锛 :0.95
# 闽 锛 :0.8888888888888888
# 闵 锛 :0.6666666666666666
# 悯 锛 :0.5
# 皿 锛 :0.6666666666666666
# 名 坌 :0.9931972789115646
# 铭 坌 :0.8888888888888888
# 茗 坌 :0.5
# 明 坌 :0.9932432432432432
# 鸣 坌 :0.9375
# 命 坌 :0.990990990990991
# 冥 坌 :0.6666666666666666
# 谬 夯 :0.8333333333333334
# 末 惫 :0.08
# 末 畚 :0.88
# 沫 畚 :0.8333333333333334
# 摸 畚 :0.9333333333333333
# 莫 畚 :0.967741935483871
# 模 畚 :0.8205128205128205
# 模 绷 :0.15384615384615385
# 膜 畚 :0.9565217391304348
# 馍 畚 :0.5
# 谟 畚 :0.5
# 漠 畚 :0.9090909090909091
# 寞 畚 :0.5
# 蓦 畚 :0.6666666666666666
# 摹 畚 :0.75
# 墨 畚 :0.9666666666666667
# 磨 畚 :0.9714285714285714
# 蘑 畚 :0.5
# 魔 畚 :0.9090909090909091
# 默 畚 :0.9411764705882353
# 万 鹁 :0.989010989010989
# 茉 畚 :0.6666666666666666
# 陌 畚 :0.75
# 无 簸 :0.996031746031746
# 某 崩 :0.8571428571428571
# 谋 崩 :0.967741935483871
# 牟 崩 :0.8
# 眸 崩 :0.5
# 哞 崩 :0.5
# 木 绷 :0.98989898989899
# 亩 绷 :0.8571428571428571
# 牧 绷 :0.96
# 母 绷 :0.9863013698630136
# 姆 绷 :0.9090909090909091
# 拇 绷 :0.6666666666666666
# 目 绷 :0.9876543209876543
# 钼 绷 :0.5
# 苜 绷 :0.5
# 幕 绷 :0.9666666666666667
# 墓 绷 :0.9230769230769231
# 慕 绷 :0.9230769230769231
# 募 绷 :0.8333333333333334
# 暮 绷 :0.75
# 沐 绷 :0.5
# 穆 绷 :0.9285714285714286
# 睦 绷 :0.75
# 牡 绷 :0.75
# 那 蹦 :0.6666666666666666
# 那 甏 :0.015151515151515152
# 那 匕 :0.30303030303030304
# 哪 蹦 :0.6666666666666666
# 哪 匕 :0.2777777777777778
# 娜 蹦 :0.7777777777777778
# 娜 笔 :0.1111111111111111
# 拿 蹦 :0.9444444444444444
# 纳 蹦 :0.9803921568627451
# 钠 蹦 :0.9166666666666666
# 呐 蹦 :0.8
# 捺 蹦 :0.6666666666666666
# 呢 甏 :0.2222222222222222
# 呢 秕 :0.6666666666666666
# 南 蹦 :0.014285714285714285
# 南 甭 :0.9714285714285714
# 南 糙 :0.007142857142857143
# 耐 嘣 :0.96875
# 乃 嘣 :0.875
# 奶 嘣 :0.9615384615384616
# 奈 嘣 :0.8571428571428571
# 萘 嘣 :0.5
# 鼐 嘣 :0.5
# 脑 泵 :0.975609756097561
# 恼 泵 :0.8888888888888888
# 瑙 泵 :0.75
# 闹 泵 :0.9444444444444444
# 挠 泵 :0.8888888888888888
# 孬 泵 :0.5
# 呶 泵 :0.5
# 楠 甭 :0.6666666666666666
# 喃 甭 :0.75
# 难 甭 :0.9886363636363636
# 男 甭 :0.9655172413793104
# 囡 甭 :0.5
# 囊 迸 :0.9411764705882353
# 馕 迸 :0.5
# 囔 迸 :0.5
# 内 匕 :0.9931972789115646
# 馁 匕 :0.6666666666666666
# 嫩 比 :0.875
# 恁 比 :0.5
# 能 毙 :0.9904761904761905
# 你 秕 :0.9230769230769231
# 尼 秕 :0.9880952380952381
# 泥 秕 :0.9777777777777777
# 昵 秕 :0.5
# 伲 秕 :0.5
# 拟 秕 :0.9285714285714286
# 倪 秕 :0.6666666666666666
# 霓 秕 :0.8
# 逆 秕 :0.9523809523809523
# 腻 秕 :0.75
# 溺 秕 :0.6666666666666666
# 匿 秕 :0.8333333333333334
# 年 妣 :0.9958333333333333
# 念 妣 :0.9791666666666666
# 捻 妣 :0.8571428571428571
# 鲶 妣 :0.5
# 粘 妣 :0.45454545454545453
# 粘 裁 :0.45454545454545453
# 拈 妣 :0.6666666666666666
# 黏 妣 :0.9166666666666666
# 碾 妣 :0.6666666666666666
# 廿 妣 :0.5
# 撵 妣 :0.5
# 蔫 妣 :0.6666666666666666
# 辇 妣 :0.5
# 娘 吡 :0.9615384615384616
# 酿 妣 :0.16666666666666666
# 酿 吡 :0.6666666666666666
# 袅 庇 :0.6666666666666666
# 尿 庇 :0.8666666666666667
# 尿 杓 :0.06666666666666667
# 聂 毖 :0.5
# 蹑 毖 :0.5
# 镊 毖 :0.5
# 捏 毖 :0.6666666666666666
# 涅 毖 :0.75
# 臬 毖 :0.5
# 镍 毖 :0.5
# 孽 毖 :0.6666666666666666
# 蘖 毖 :0.8
# ...
# 协 膊 :0.9714285714285714
# 胁 膊 :0.75
# 鞋 膊 :0.95
# 卸 膊 :0.9090909090909091
# 蟹 膊 :0.8
# 携 膊 :0.8571428571428571
# 懈 膊 :0.75
# 斜 膊 :0.9565217391304348
# 械 膊 :0.9565217391304348
# 邪 膊 :0.875
# 歇 膊 :0.9
# 蝎 膊 :0.5
# 泄 膊 :0.9
# 谐 膊 :0.9
# 偕 膊 :0.6666666666666666
# 血 膊 :0.4107142857142857
# 血 钹 :0.5803571428571429
# 屑 膊 :0.8333333333333334
# 挟 膊 :0.6666666666666666
# 楔 膊 :0.5
# 榍 膊 :0.5
# 亵 膊 :0.5
# 叶 膊 :0.016666666666666666
# 叶 钚 :0.9666666666666667
# 新 搏 :0.9941176470588236
# 薪 搏 :0.8888888888888888
# 心 搏 :0.9970845481049563
# 芯 搏 :0.6666666666666666
# 信 搏 :0.9915966386554622
# 欣 搏 :0.9375
# 昕 搏 :0.5
# 辛 搏 :0.967741935483871
# 锌 搏 :0.8888888888888888
# 馨 搏 :0.6666666666666666
# 歆 搏 :0.5
# 寻 钵 :0.9230769230769231
# 衅 搏 :0.6666666666666666
# 性 播 :0.9966216216216216
# 姓 播 :0.8888888888888888
# 型 播 :0.9818181818181818
# 星 播 :0.98989898989899
# 醒 播 :0.9230769230769231
# 腥 播 :0.75
# 猩 播 :0.75
# 惺 播 :0.6666666666666666
# 形 播 :0.9913793103448276
# 邢 播 :0.6666666666666666
# 刑 播 :0.975609756097561
# 幸 播 :0.9230769230769231
# 悻 播 :0.6666666666666666
# 杏 播 :0.8333333333333334
# 兴 播 :0.9866666666666667
# 陉 播 :0.5
# 擤 播 :0.5
# 熊 驳 :0.9230769230769231
# 雄 驳 :0.9791666666666666
# 凶 驳 :0.9375
# 汹 驳 :0.8333333333333334
# 兄 驳 :0.9523809523809523
# 匈 驳 :0.75
# 胸 驳 :0.9545454545454546
# 修 帛 :0.9855072463768116
# 秀 帛 :0.95
# 休 帛 :0.9705882352941176
# 绣 帛 :0.875
# 锈 帛 :0.8571428571428571
# 袖 帛 :0.9090909090909091
# 羞 帛 :0.9090909090909091
# 溴 帛 :0.8571428571428571
# 嗅 帛 :0.6666666666666666
# 朽 帛 :0.8571428571428571
# 需 擘 :0.9333333333333333
# 徐 擘 :0.6666666666666666
# 叙 擘 :0.75
# 许 擘 :0.9523809523809523
# 须 擘 :0.9
# 续 擘 :0.96
# 序 擘 :0.9655172413793104
# 虚 擘 :0.9722222222222222
# 墟 擘 :0.6666666666666666
# 蓄 擘 :0.8571428571428571
# 婿 擘 :0.75
# 旭 擘 :0.75
# 绪 擘 :0.9090909090909091
# 吁 擘 :0.6
# 吁 哺 :0.2
# 恤 擘 :0.8
# 煦 擘 :0.5
# 诩 擘 :0.5
# 栩 擘 :0.6666666666666666
# 蓿 擘 :0.5
# 絮 擘 :0.8333333333333334
# 宣 檗 :0.967741935483871
# 喧 檗 :0.75
# 暄 檗 :0.5
# 渲 檗 :0.5
# 选 檗 :0.9891304347826086
# 旋 檗 :0.9545454545454546
# 璇 檗 :0.5
# 漩 檗 :0.5
# 轩 檗 :0.8
# 悬 檗 :0.9444444444444444
# 玄 檗 :0.8571428571428571
# 炫 檗 :0.5
# 绚 檗 :0.6666666666666666
# 学 钹 :0.9977426636568849
# 雪 钹 :0.9722222222222222
# 薛 钹 :0.5
# 穴 钹 :0.9166666666666666
# 靴 钹 :0.5
# 讯 钵 :0.9473684210526315
# 汛 钵 :0.8333333333333334
# 迅 钵 :0.8
# 训 钵 :0.9523809523809523
# 驯 钵 :0.8333333333333334
# 逊 钵 :0.8888888888888888
# 尊 彩 :0.9285714285714286
# 旬 钵 :0.8571428571428571
# 询 钵 :0.875
# 徇 钵 :0.75
# 殉 钵 :0.8
# 荀 钵 :0.75
# 巡 钵 :0.9545454545454546
# 勋 钵 :0.875
# 循 钵 :0.9473684210526315
# 熏 钵 :0.8
# 薰 钵 :0.5
# 亚 踣 :0.9927536231884058
# 哑 踣 :0.875
# 痖 踣 :0.5
# 压 踣 :0.9903846153846154
# 雅 踣 :0.9714285714285714
# 鸭 踣 :0.9230769230769231
# 押 踣 :0.9333333333333333
# 牙 踣 :0.9655172413793104
# 蚜 踣 :0.6666666666666666
# 伢 踣 :0.5
# 鸦 踣 :0.8
# 讶 踣 :0.5
# 芽 踣 :0.9473684210526315
# 涯 踣 :0.75
# 崖 踣 :0.875
# 衙 踣 :0.5
# 丫 踣 :0.6666666666666666
# 严 卜 :0.9772727272727273
# 俨 卜 :0.5
# 砚 卜 :0.5
# 言 卜 :0.9885057471264368
# 唁 卜 :0.6666666666666666
# 盐 卜 :0.9803921568627451
# 焰 卜 :0.9090909090909091
# 阎 卜 :0.6666666666666666
# 眼 卜 :0.9894736842105263
# 烟 卜 :0.9583333333333334
# 烟 怖 :0.020833333333333332
# 咽 卜 :0.5
# 咽 钚 :0.25
# 胭 卜 :0.5
# 燕 卜 :0.9375
# 演 卜 :0.9795918367346939
# 验 卜 :0.9705882352941176
# 艳 卜 :0.8571428571428571
# 岩 卜 :0.9642857142857143
# 延 卜 :0.96
# 蜒 卜 :0.5
# 筵 卜 :0.5
# 沿 卜 :0.9565217391304348
# 炎 卜 :0.9583333333333334
# 研 卜 :0.96
# 谚 卜 :0.75
# 宴 卜 :0.9
# 堰 卜 :0.5
# 偃 卜 :0.5
# 颜 卜 :0.9
# 焉 卜 :0.5
# 嫣 卜 :0.75
# 雁 卜 :0.8333333333333334
# 奄 卜 :0.8
# 淹 卜 :0.6666666666666666
# 掩 卜 :0.9
# 阉 卜 :0.5
# 衍 卜 :0.8333333333333334
# 厌 卜 :0.8888888888888888
# 檐 卜 :0.6666666666666666
# 湮 卜 :0.5
# 殷 怖 :0.8571428571428571
# 兖 卜 :0.5
# 阳 亳 :0.9883720930232558
# 养 亳 :0.9875
# 羊 亳 :0.967741935483871
# 样 亳 :0.9841269841269841
# 洋 亳 :0.9868421052631579
# 徉 亳 :0.5
# 佯 亳 :0.5
# 氧 亳 :0.9777777777777777
# 痒 亳 :0.8571428571428571
# 漾 亳 :0.6666666666666666
# 恙 亳 :0.5
# 央 亳 :0.9375
# 秧 亳 :0.9090909090909091
# 泱 亳 :0.6666666666666666
# 鞅 亳 :0.5
# 殃 亳 :0.75
# 鸯 亳 :0.5
# 杨 亳 :0.9583333333333334
# 扬 亳 :0.9743589743589743
# 炀 亳 :0.5
# 疡 亳 :0.6666666666666666
# 仰 亳 :0.9375
# 要 不 :0.9886363636363636
# 腰 不 :0.9473684210526315
# 药 不 :0.9846153846153847
# 姚 不 :0.5
# 耀 不 :0.9090909090909091
# 幺 不 :0.6666666666666666
# 吆 不 :0.6666666666666666
# 尧 不 :0.6666666666666666
# 瑶 不 :0.8
# 摇 不 :0.967741935483871
# 谣 不 :0.8571428571428571
# 遥 不 :0.9230769230769231
# 徭 不 :0.5
# 窑 不 :0.875
# 咬 不 :0.875
# 邀 不 :0.8888888888888888
# 夭 不 :0.5
# 妖 不 :0.8
# 杳 不 :0.5
# 钥 不 :0.5
# 约 不 :0.027777777777777776
# 约 埔 :0.9583333333333334
# 肴 不 :0.5
# 也 钚 :0.9166666666666666
# 业 钚 :0.9961538461538462
# 夜 钚 :0.9827586206896551
# 页 钚 :0.8571428571428571
# 液 钚 :0.9791666666666666
# 掖 钚 :0.5
# 腋 钚 :0.75
# 野 钚 :0.9772727272727273
# 冶 钚 :0.8888888888888888
# 爷 钚 :0.9642857142857143
# 耶 钚 :0.9090909090909091
# 椰 钚 :0.5
# 曳 钚 :0.5
# 谒 钚 :0.6666666666666666
# 一 布 :0.9979959919839679
# 以 布 :0.987012987012987
# 已 布 :0.9473684210526315
# 异 布 :0.9827586206896551
# 乙 布 :0.9666666666666667
# 亿 布 :0.8333333333333334
# 忆 布 :0.875
# 艺 布 :0.9814814814814815
# 呓 布 :0.5
# 易 布 :0.9848484848484849
# 意 布 :0.9931506849315068
# 臆 布 :0.75
# 噫 布 :0.5
# 亦 布 :0.75
# 益 布 :0.9772727272727273
# 溢 布 :0.875
# 缢 布 :0.5
# 依 布 :0.967741935483871
# 铱 布 :0.5
# 医 布 :0.9830508474576272
# 宜 布 :0.9629629629629629
# 谊 布 :0.9
# 义 布 :0.9949238578680203
# 仪 布 :0.9545454545454546
# 议 布 :0.9905660377358491
# 蚁 布 :0.75
# 衣 布 :0.9848484848484849
# 裔 布 :0.6666666666666666
# 伊 布 :0.9615384615384616
# 咿 布 :0.5
# 移 布 :0.967741935483871
# 毅 布 :0.9090909090909091
# 译 布 :0.9444444444444444
# 驿 布 :0.5
# 绎 布 :0.5
# 弋 布 :0.5
# 奕 布 :0.75
# 翼 布 :0.9411764705882353
# 疑 布 :0.9655172413793104
# 沂 布 :0.6666666666666666
# 逸 布 :0.8333333333333334
# 役 布 :0.9523809523809523
# 邑 布 :0.5
# 轶 布 :0.5
# 矣 布 :0.5
# 怡 布 :0.75
# 贻 布 :0.5
# 饴 布 :0.6666666666666666
# 夷 布 :0.8888888888888888
# 姨 布 :0.9615384615384616
# 胰 布 :0.8
# 咦 布 :0.5
# 抑 布 :0.9
# 椅 布 :0.875
# 倚 布 :0.8333333333333334
# 彝 布 :0.6666666666666666
# 壹 布 :0.6666666666666666
# 颐 布 :0.75
# 迤 布 :0.6666666666666666
# 翌 布 :0.6666666666666666
# 黟 布 :0.5
# 诣 布 :0.5
# 揖 布 :0.5
# 肄 布 :0.5
# 因 怖 :0.9803921568627451
# 姻 怖 :0.9
# 茵 怖 :0.5
# 引 怖 :0.9833333333333333
# 蚓 怖 :0.5
# 印 怖 :0.9824561403508771
# 银 怖 :0.9841269841269841
# 垠 怖 :0.5
# 音 怖 :0.9925373134328358
# 隐 怖 :0.9523809523809523
# 尹 怖 :0.6666666666666666
# 饮 怖 :0.9411764705882353
# 阴 怖 :0.9736842105263158
# 荫 怖 :0.875
# 瘾 怖 :0.75
# 寅 怖 :0.5
# 淫 怖 :0.875
# 吟 怖 :0.8333333333333334
# 胤 怖 :0.5
# 映 钸 :0.9333333333333333
# 瑛 钸 :0.6666666666666666
# 英 钸 :0.984375
# 应 钸 :0.9911504424778761
# 硬 钸 :0.9722222222222222
# 迎 钸 :0.967741935483871
# 影 钸 :0.9850746268656716
# 鹰 钸 :0.8571428571428571
# 盈 钸 :0.9333333333333333
# 赢 钸 :0.8
# 嬴 钸 :0.5
# 颍 钸 :0.6666666666666666
# 颖 钸 :0.8333333333333334
# 婴 钸 :0.8
# 樱 钸 :0.75
# 鹦 钸 :0.5
# 营 钸 :0.9846153846153847
# 莹 钸 :0.6666666666666666
# 荧 钸 :0.8
# 萦 钸 :0.5
# 萤 钸 :0.6666666666666666
# 滢 钸 :0.5
# 蝇 钸 :0.6666666666666666
# 膺 钸 :0.5
# 罂 钸 :0.5
# 哟 卟 :0.8571428571428571
# 育 哺 :0.987012987012987
# 唷 卟 :0.5
# 用 补 :0.9950738916256158
# 拥 补 :0.9166666666666666
# 佣 补 :0.8333333333333334
# 甬 补 :0.5
# 俑 补 :0.8
# 蛹 补 :0.6666666666666666
# 踊 补 :0.5
# 勇 补 :0.9565217391304348
# 雍 补 :0.5
# 臃 补 :0.5
# 壅 补 :0.5
# 永 补 :0.9761904761904762
# 泳 补 :0.9230769230769231
# 咏 补 :0.5
# 庸 补 :0.9333333333333333
# 有 捕 :0.9959514170040485
# 由 捕 :0.9782608695652174
# 油 捕 :0.9937106918238994
# 釉 捕 :0.6666666666666666
# 铀 捕 :0.6666666666666666
# 邮 捕 :0.96875
# 又 捕 :0.8333333333333334
# 犹 捕 :0.9090909090909091
# 优 捕 :0.96875
# 忧 捕 :0.9411764705882353
# 尤 捕 :0.75
# 鱿 捕 :0.6666666666666666
# 友 捕 :0.975
# 游 捕 :0.9873417721518988
# 右 捕 :0.9565217391304348
# 佑 捕 :0.6666666666666666
# 幼 捕 :0.9523809523809523
# 呦 捕 :0.5
# 黝 捕 :0.75
# 幽 捕 :0.9285714285714286
# 诱 捕 :0.9166666666666666
# 莠 捕 :0.5
# 悠 捕 :0.9090909090909091
# 酉 捕 :0.5
# 攸 捕 :0.5
# 莜 捕 :0.5
# 与 哺 :0.96
# 屿 哺 :0.6666666666666666
# 于 哺 :0.99
# 宇 哺 :0.9285714285714286
# 芋 哺 :0.75
# 迂 哺 :0.5
# 盂 哺 :0.5
# 余 哺 :0.9795918367346939
# 玉 哺 :0.9767441860465116
# 鱼 哺 :0.9864864864864865
# 渔 哺 :0.9583333333333334
# 域 哺 :0.9375
# 雨 哺 :0.9838709677419355
# 誉 哺 :0.9333333333333333
# 予 哺 :0.9090909090909091
# 豫 哺 :0.8571428571428571
# 预 哺 :0.9824561403508771
# 语 哺 :0.9873417721518988
# 龉 哺 :0.5
# 裕 哺 :0.8571428571428571
# 浴 哺 :0.9333333333333333
# 峪 哺 :0.5
# 欲 哺 :0.95
# 俞 哺 :0.5
# 喻 哺 :0.8333333333333334
# 愉 哺 :0.6666666666666666
# 渝 哺 :0.6666666666666666
# 榆 哺 :0.6666666666666666
# 瑜 哺 :0.6666666666666666
# 谕 哺 :0.6666666666666666
# 觎 哺 :0.5
# 愈 哺 :0.9090909090909091
# 逾 哺 :0.75
# 郁 哺 :0.9230769230769231
# 禹 哺 :0.75
# 娱 哺 :0.8
# 羽 哺 :0.9375
# 禺 哺 :0.5
# 隅 哺 :0.6666666666666666
# 愚 哺 :0.9
# 遇 哺 :0.9565217391304348
# 寓 哺 :0.8888888888888888
# 御 哺 :0.875
# 狱 哺 :0.9090909090909091
# 淤 哺 :0.75
# 瘀 哺 :0.75
# 煜 哺 :0.5
# 舆 哺 :0.6666666666666666
# 熨 逋 :0.6666666666666666
# 驭 哺 :0.5
# 粥 灿 :0.6666666666666666
# 元 晡 :0.9866666666666667
# 沅 晡 :0.5
# 远 晡 :0.9855072463768116
# 园 晡 :0.9803921568627451
# 原 晡 :0.9924242424242424
# 源 晡 :0.9811320754716981
# 愿 晡 :0.967741935483871
# 员 晡 :0.9884393063583815
# 员 逋 :0.005780346820809248
# 圆 晡 :0.98
# 院 晡 :0.9913793103448276
# 袁 晡 :0.75
# 猿 晡 :0.6666666666666666
# 辕 晡 :0.5
# 缘 晡 :0.9444444444444444
# 橼 晡 :0.5
# 垣 晡 :0.5
# 渊 晡 :0.8333333333333334
# 苑 晡 :0.6666666666666666
# 援 晡 :0.95
# 怨 晡 :0.9333333333333333
# 冤 晡 :0.9166666666666666
# 鸳 晡 :0.5
# 月 埔 :0.9897959183673469
# 越 埔 :0.972972972972973
# 跃 埔 :0.9285714285714286
# 岳 埔 :0.9090909090909091
# 粤 埔 :0.8
# 悦 埔 :0.875
# 阅 埔 :0.9444444444444444
# 云 逋 :0.9841269841269841
# 耘 逋 :0.5
# 酝 逋 :0.5
# 纭 逋 :0.6666666666666666
# 运 逋 :0.9933774834437086
# 陨 逋 :0.6666666666666666
# 晕 逋 :0.8571428571428571
# 蕴 逋 :0.75
# 孕 逋 :0.9230769230769231
# 允 逋 :0.8
# 匀 逋 :0.9
# 韵 逋 :0.9166666666666666
# 杂 簿 :0.9818181818181818
# 扎 簿 :0.42857142857142855
# 扎 睬 :0.5238095238095238
# 咋 簿 :0.5
# 咋 睬 :0.25
# 砸 簿 :0.75
# 在 埠 :0.9868421052631579
# 再 埠 :0.9411764705882353
# 再 醭 :0.029411764705882353
# 哉 埠 :0.6666666666666666
# 栽 埠 :0.8571428571428571
# 载 埠 :0.9761904761904762
# 灾 埠 :0.9655172413793104
# 宰 埠 :0.875
# 仔 埠 :0.3333333333333333
# 仔 拆 :0.5555555555555556
# 崽 埠 :0.5
# 咱 部 :0.8571428571428571
# 赞 部 :0.9565217391304348
# 暂 部 :0.9
# 糌 部 :0.5
# 錾 部 :0.5
# 脏 步 :0.9333333333333333
# 葬 步 :0.9473684210526315
# 赃 步 :0.8888888888888888
# 奘 步 :0.5
# 枣 醭 :0.8571428571428571
# 早 矮 :0.0196078431372549
# 早 醭 :0.9607843137254902
# 造 醭 :0.9857142857142858
# 糟 醭 :0.9090909090909091
# 遭 醭 :0.8888888888888888
# 灶 醭 :0.8888888888888888
# 凿 醭 :0.8571428571428571
# 噪 醭 :0.8333333333333334
# 澡 醭 :0.8333333333333334
# 躁 醭 :0.8333333333333334
# 燥 醭 :0.8888888888888888
# 藻 醭 :0.9
# 皂 醭 :0.8571428571428571
# 蚤 醭 :0.6666666666666666
# 则 瓿 :0.9705882352941176
# 泽 瓿 :0.9411764705882353
# 择 瓿 :0.9090909090909091
# 责 瓿 :0.967741935483871
# 啧 瓿 :0.75
# 仄 瓿 :0.5
# 贼 擦 :0.8571428571428571
# 怎 嚓 :0.9166666666666666
# 增 礤 :0.9777777777777777
# 赠 礤 :0.9
# 憎 礤 :0.8
# 综 礤 :0.14285714285714285
# 综 才 :0.7857142857142857
# 自 拆 :0.995475113122172
# 子 拆 :0.9983739837398374
# 籽 拆 :0.8333333333333334
# 字 拆 :0.9866666666666667
# 资 拆 :0.9928057553956835
# 姿 拆 :0.8888888888888888
# 咨 拆 :0.75
# 恣 拆 :0.6666666666666666
# 谘 拆 :0.8
# 紫 拆 :0.9523809523809523
# 滋 拆 :0.9230769230769231
# 淄 拆 :0.6666666666666666
# 辎 拆 :0.5
# 孜 拆 :0.75
# 梓 拆 :0.6666666666666666
# 秭 拆 :0.5
# 渍 拆 :0.8
# 吱 拆 :0.2857142857142857
# 吱 餐 :0.5714285714285714
# 姊 拆 :0.5
# 呲 安 :0.5
# 龇 拆 :0.5
# 赀 拆 :0.5
# 滓 拆 :0.5
# 总 才 :0.9907407407407407
# 宗 才 :0.9736842105263158
# 纵 才 :0.9583333333333334
# 棕 才 :0.9090909090909091
# 踪 才 :0.8888888888888888
# 粽 才 :0.6666666666666666
# 鬃 才 :0.6666666666666666
# 走 材 :0.9830508474576272
# 邹 材 :0.75
# 奏 材 :0.9583333333333334
# 揍 材 :0.5
# 足 财 :0.9821428571428571
# 组 财 :0.9857142857142858
# 租 财 :0.9629629629629629
# 祖 财 :0.9705882352941176
# 阻 财 :0.9714285714285714
# 诅 财 :0.5
# 族 财 :0.9901960784313726
# 卒 氨 :0.16666666666666666
# 卒 财 :0.6666666666666666
# 钻 采 :0.9411764705882353
# 赚 藏 :0.8
# 攥 采 :0.5
# 纂 采 :0.6666666666666666
# 躜 采 :0.5
# 最 菜 :0.9705882352941176
# 罪 菜 :0.975
# 嘴 菜 :0.9375
# 醉 菜 :0.9230769230769231
# 鳟 彩 :0.6666666666666666
# 遵 彩 :0.9166666666666666
# 作 踩 :0.9950738916256158
# 昨 踩 :0.875
# 柞 踩 :0.5
# 做 踩 :0.9642857142857143
# 坐 踩 :0.9615384615384616
# 唑 踩 :0.5
# 座 踩 :0.9545454545454546
# 左 踩 :0.9565217391304348
# 佐 踩 :0.8
# 琢 踩 :0.2
# 琢 沧 :0.6
# 札 睬 :0.75
# 乍 睬 :0.5
# 炸 睬 :0.9285714285714286
# 诈 睬 :0.9090909090909091
# 蚱 睬 :0.5
# 榨 睬 :0.8
# 渣 睬 :0.9285714285714286
# 闸 睬 :0.9090909090909091
# 咤 睬 :0.5
# 眨 睬 :0.8
# 铡 睬 :0.6666666666666666
# 寨 蔡 :0.875
# 债 蔡 :0.9642857142857143
# 摘 蔡 :0.9285714285714286
# 窄 蔡 :0.75
# 宅 蔡 :0.75
# 斋 蔡 :0.8
# 占 裁 :0.9655172413793104
# 站 裁 :0.9803921568627451
# 沾 裁 :0.75
# 战 裁 :0.9932885906040269
# 毡 裁 :0.8333333333333334
# 展 裁 :0.9821428571428571
# 辗 裁 :0.5
# 湛 裁 :0.8
# 詹 裁 :0.5
# 瞻 裁 :0.75
# 斩 裁 :0.8333333333333334
# 崭 裁 :0.75
# 栈 裁 :0.6666666666666666
# 盏 裁 :0.5
# 绽 裁 :0.75
# 张 猜 :0.9803921568627451
# 账 猜 :0.5
# 胀 猜 :0.9166666666666666
# 帐 猜 :0.9615384615384616
# 涨 猜 :0.9166666666666666
# 章 猜 :0.9761904761904762
# 障 猜 :0.9166666666666666
# 漳 猜 :0.6666666666666666
# 樟 猜 :0.75
# 璋 猜 :0.5
# 彰 猜 :0.8
# 掌 猜 :0.9411764705882353
# 丈 猜 :0.9285714285714286
# 仗 猜 :0.9230769230769231
# 杖 猜 :0.8
# 找 参 :0.9230769230769231
# 赵 参 :0.8
# 着 参 :0.2962962962962963
# 着 骖 :0.42592592592592593
# 着 沧 :0.25925925925925924
# 照 参 :0.9821428571428571
# 兆 参 :0.8888888888888888
# 昭 参 :0.8333333333333334
# 招 参 :0.9705882352941176
# 沼 参 :0.8333333333333334
# 诏 参 :0.75
# 罩 参 :0.9230769230769231
# 肇 参 :0.75
# 钊 参 :0.6666666666666666
# 爪 参 :0.2857142857142857
# 爪 粲 :0.5714285714285714
# 这 骖 :0.8888888888888888
# 这 掺 :0.07407407407407407
# 者 骖 :0.9911504424778761
# 浙 骖 :0.875
# 哲 骖 :0.9230769230769231
# 蛰 骖 :0.5
# 蔗 骖 :0.6666666666666666
# 遮 骖 :0.9090909090909091
# 辙 骖 :0.5
# 辄 骖 :0.5
# 褶 骖 :0.6666666666666666
# 真 惨 :0.9838709677419355
# 镇 惨 :0.9655172413793104
# 针 惨 :0.9736842105263158
# 振 惨 :0.96875
# 赈 惨 :0.5
# 震 惨 :0.9565217391304348
# 珍 惨 :0.9545454545454546
# 诊 惨 :0.9333333333333333
# 疹 惨 :0.5
# 阵 惨 :0.9743589743589743
# 贞 惨 :0.8333333333333334
# 侦 惨 :0.9
# 祯 惨 :0.5
# 帧 残 :0.5
# 圳 惨 :0.6666666666666666
# 枕 惨 :0.8
# 斟 惨 :0.5
# 箴 惨 :0.5
# 朕 惨 :0.5
# 砧 惨 :0.6666666666666666
# 正 残 :0.9920634920634921
# 证 残 :0.9871794871794872
# 政 残 :0.9941176470588236
# 征 残 :0.9714285714285714
# 整 残 :0.9787234042553191
# 症 残 :0.9444444444444444
# 郑 残 :0.8888888888888888
# 争 残 :0.9875
# 挣 残 :0.8333333333333334
# 睁 残 :0.5
# 铮 残 :0.75
# 峥 残 :0.5
# 狰 残 :0.5
# 筝 残 :0.6666666666666666
# 蒸 残 :0.9583333333333334
# 拯 残 :0.5
# 至 餐 :0.9736842105263158
# 侄 餐 :0.75
# 致 餐 :0.9767441860465116
# 窒 餐 :0.5
# 之 餐 :0.9891304347826086
# 芝 餐 :0.875
# 只 餐 :0.9565217391304348
# 职 餐 :0.9846153846153847
# 织 餐 :0.9836065573770492
# 帜 餐 :0.8571428571428571
# 制 餐 :0.995575221238938
# 志 餐 :0.9850746268656716
# 支 餐 :0.9838709677419355
# 枝 餐 :0.95
# 肢 餐 :0.9230769230769231
# 治 餐 :0.9903846153846154
# 直 餐 :0.9864864864864865
# 值 餐 :0.9830508474576272
# 植 餐 :0.975609756097561
# 埴 餐 :0.5
# 置 餐 :0.967741935483871
# 质 餐 :0.9902912621359223
# 纸 餐 :0.9803921568627451
# 旨 餐 :0.875
# 酯 餐 :0.8333333333333334
# 指 餐 :0.9882352941176471
# 脂 餐 :0.9642857142857143
# 知 餐 :0.9859154929577465
# 蜘 餐 :0.5
# 智 餐 :0.9545454545454546
# 执 餐 :0.9615384615384616
# 止 餐 :0.9705882352941176
# 址 餐 :0.9
# 趾 餐 :0.5
# 滞 餐 :0.8888888888888888
# 汁 餐 :0.9
# 掷 餐 :0.8333333333333334
# 踯 餐 :0.5
# 炙 餐 :0.5
# 稚 餐 :0.75
# 痔 餐 :0.6666666666666666
# 挚 餐 :0.8
# 秩 餐 :0.75
# 痣 餐 :0.5
# 咫 餐 :0.5
# 中 蚕 :0.9971428571428571
# 忠 蚕 :0.9642857142857143
# 钟 蚕 :0.9583333333333334
# 肿 蚕 :0.9285714285714286
# 仲 蚕 :0.9230769230769231
# 众 蚕 :0.9772727272727273
# 踵 蚕 :0.6666666666666666
# 终 蚕 :0.9714285714285714
# 衷 蚕 :0.9090909090909091
# 冢 蚕 :0.5
# 州 灿 :0.9882352941176471
# 洲 灿 :0.972972972972973
# 周 灿 :0.9846153846153847
# 舟 灿 :0.9166666666666666
# 骤 灿 :0.8
# 皱 灿 :0.875
# 轴 灿 :0.9787234042553191
# 妯 灿 :0.5
# 宙 灿 :0.8888888888888888
# 肘 灿 :0.5
# 昼 灿 :0.8
# 绉 灿 :0.5
# 诌 灿 :0.6666666666666666
# 胄 灿 :0.5
# 咒 灿 :0.8333333333333334
# 帚 灿 :0.6666666666666666
# 主 惭 :0.9967845659163987
# 住 惭 :0.9795918367346939
# 驻 惭 :0.9375
# 柱 惭 :0.96
# 注 惭 :0.9722222222222222
# 蛀 惭 :0.5
# 诸 惭 :0.9375
# 猪 惭 :0.9523809523809523
# 煮 惭 :0.6666666666666666
# 著 惭 :0.9166666666666666
# 著 沧 :0.041666666666666664
# 铸 惭 :0.9444444444444444
# 伫 惭 :0.5
# 贮 惭 :0.9
# 朱 惭 :0.9166666666666666
# 珠 惭 :0.9705882352941176
# 株 惭 :0.9230769230769231
# 蛛 惭 :0.5
# 侏 惭 :0.6666666666666666
# 诛 惭 :0.5
# 洙 惭 :0.5
# 助 惭 :0.975
# 竹 惭 :0.9629629629629629
# 筑 惭 :0.9736842105263158
# 逐 惭 :0.96
# 祝 惭 :0.9333333333333333
# 嘱 惭 :0.8
# 瞩 惭 :0.75
# 躅 惭 :0.5
# 烛 惭 :0.75
# 竺 惭 :0.5
# 抓 粲 :0.9333333333333333
# 拽 璨 :0.6666666666666666
# 转 璨 :0.07339449541284404
# 转 藏 :0.9174311926605505
# 专 藏 :0.9868421052631579
# 砖 藏 :0.9333333333333333
# 撰 藏 :0.8571428571428571
# 篆 藏 :0.6666666666666666
# 装 仓 :0.9887640449438202
# 庄 仓 :0.9714285714285714
# 壮 仓 :0.9736842105263158
# 桩 仓 :0.75
# 撞 仓 :0.9
# 状 仓 :0.9803921568627451
# 妆 仓 :0.8333333333333334
# 追 舱 :0.9696969696969697
# 坠 舱 :0.875
# 锥 舱 :0.9
# 缀 舱 :0.6666666666666666
# 准 苍 :0.9838709677419355
# 谆 苍 :0.6666666666666666
# 肫 苍 :0.5
# 卓 沧 :0.9090909090909091
# 桌 沧 :0.9473684210526315
# 镯 沧 :0.75
# 灼 沧 :0.875
# 酌 沧 :0.8333333333333334
# 捉 沧 :0.9
# 浊 沧 :0.8571428571428571
# 拙 沧 :0.8
# 茁 沧 :0.6666666666666666
# 啄 沧 :0.75
# 擢 沧 :0.5
# 浞 沧 :0.6666666666666666
# 斫 沧 :0.5
# 翱 屏 :0.5
# 抱 吖 :0.5
# 爹 暧 :0.9
# 澜 坳 :0.8
# 滤 暴 :0.8333333333333334
# 丧 槽 :0.9333333333333333
# 呀 表 :0.9523809523809523
# 赘 踣 :0.8571428571428571
# 荸 舱 :0.75
# 蔟 挨 :0.6666666666666666
# 捱 氨 :0.5
# 哔 啊 :0.8
# 啵 挨 :0.5
# 嗯 艾 :0.5
# 嗲 糙 :0.42857142857142855
# 嗲 侧 :0.42857142857142855
# 饽 伧 :0.8
# 涔 艾 :0.6666666666666666
# 孢 嘈 :0.6666666666666666
# 胫 暧 :0.75
# 箅 磅 :0.6666666666666666
# 鏖 挨 :0.5
# 礴 吖 :0.3333333333333333
# 礴 艾 :0.3333333333333333
# 邃 杓 :0.5
# 擎 扁 :0.5
# 榈 槽 :0.5

# %%
def print_pi(pi, hzl):
    for i in range(pi):
        if(pi[i] > 0):
            print(hzl[i] + " " + pi[i])

# %%
def viterbi(obs, pyd, length, pydic, pi, a, b, hzdic, hzl):
    obs += ' a'
    OBS = obs.split(" ")
    T = len(OBS)
    N = length
    idx = pyd[OBS[0]]
    eta = [[0 for js in range(N)] for it in range(T)]
    phi = [[0 for js in range(N)] for it in range(T)]
    ### initialize
    pre_py = pydic[OBS[0]]
    for item in range(len(pre_py)):
        hzidx = hzdic[pre_py[item]][0]
        eta[0][item] = pi[hzidx]*b[hzidx][idx]

    for t in range(1, T):
        currO = OBS[t] # 这是一个拼音
        idxo = pyd[currO]
        ot_py = pydic[currO] #当前状态的拼音对应的汉字集
        for jj in range(len(ot_py)):
            j = ot_py[jj] #当前汉字
            ot_pre_py = pydic[OBS[t - 1]] #前一个状态的所有汉字对应
            idx_j = hzdic[j][0]
            maxn = -1 #
            argmaxn = 0
            for ii in range(len(ot_pre_py)):
                i = ot_pre_py[ii]
                idx_i = hzdic[i][0]
                if maxn < eta[t-1][ii] * a[idx_i][idx_j]:
                    maxn = eta[t-1][ii] * a[idx_i][idx_j]
                    argmaxn = idx_i
            eta[t][jj] = maxn * b[idx_j][idxo]
            phi[t][jj] = argmaxn
    
    ##接下来是做回溯的部分
    word_result = ""
    for i in range(1, len(phi)):
        idxt = max(phi[i])
        word_result +=hzl[idxt]
    return word_result

# %%
def transfer(a, b, pi, dic, hzl, pyl, pyd, pyhzdic):
    a_new = dict()
    b_new = dict()
    pi_new = dict()
    for i in range(len(a)):
        a_new[hzl[i]] = dict()
        for j in range(len(a[0])):
            a_new[hzl[i]][hzl[j]] = a[i][j]
            
    for j in range(len(b)):
        b_new[hzl[i]] = dict()
        for j in range(len(b[0])):
            b_new[hzl[i]][pyl[j]] = b[i][j]
            
    for i in range(len(pi)):
        pi_new[hzl[i]] = pi[i]
    return a_new, b_new, pi_new

# %%
length = 0
for i in pyhzdic.values():
    length = max(length, len(i))
print(length)
# Out:
# 111

# %%
def display():
    count_all = 0
    count_true = 0
    file = "test.txt"
    now_chinese = []
    test_result = []
    with open(file, 'r', encoding='utf8') as fin:
        i = 0
        for line in fin.readlines():
            line = line.strip('\n')
            if(i % 2 != 0):
                now_chinese.append(line)
            else:
                phi = viterbi(line, pyd, length,pyhzdic, pi, a, b, dic, hzl)
                test_result.append(phi)
            i+=1

    for j in range(len(now_chinese)):
        count_all += len(now_chinese[j])
        print("原文：" + now_chinese[j])
        print("训练结果：" + test_result[j])
        for x in range(len(now_chinese[j])):
            if now_chinese[j][x] == test_result[j][x]:
                count_true +=1
    
    print("正确率：" + str(count_true/count_all))

# %%
display()
# Out:
# 原文：今天晚上有好看的电影
# 训练结果：今天晚上有好看的电映
# 原文：北京奥运会开幕式非常精彩
# 训练结果：备京奥运会开幕式非常精才
# 原文：全国人民代表大会在北京人民大会堂隆重召开
# 训练结果：全国人民代表大会在北京人民大会堂隆中找开
# 原文：金庸的武侠小说非常精彩
# 训练结果：今庸得武侠小说非常精才
# 原文：你的世界会变得更精彩
# 训练结果：尼的世界会变得更精才
# 原文：在天安门广场举行了隆重的阅兵式
# 训练结果：在天安门广场举省了隆中的阅兵是
# 原文：逻辑代数有些常用的基本公式
# 训练结果：逻辑代数有些常用得基本公是
# 原文：请大家选择你觉得可以的时间
# 训练结果：卿达家选择你决得可以的时件
# 原文：具有良好的沟通能力和交流能力
# 训练结果：具有良好的沟通能力和交流能丽
# 原文：人在阅读时是从左到右逐字读入的
# 训练结果：人在阅渎时是从左到右逐字渎入的
# 原文：减少课程的课时是十分科学的
# 训练结果：减少课程的课时事事分科学的
# 原文：我戴着一副黑框眼镜
# 训练结果：我戴这一副黑框眼竞
# 原文：他钢琴弹得不错
# 训练结果：他钢琴摊得不错
# 原文：小朋友们都喜欢去郊游
# 训练结果：小朋友们都喜欢去郊有
# 原文：这个玩具很有趣
# 训练结果：遮个玩具很有区
# 原文：他很生气
# 训练结果：他很生气
# 原文：今天天气很好
# 训练结果：今天天气很好
# 原文：我们去散步吧
# 训练结果：我们去散步巴
# 原文：大家可能不知道
# 训练结果：打家可能不知岛
# 原文：我们宿舍的灯坏了
# 训练结果：我们宿舍的灯坏了
# 正确率：0.8428571428571429
